# %% [markdown]
# MOABB to NY format
#
# .CSV to NY
#
# this code convert the data sets in .CSV format to NY format which it can be easily read in Julia and Python.
#
# The .npz file holds the data and the stimulation vector while the .yml file holds the metadata.
#
# It has been specifically conceived for BCI data.
#
# This script is for BI2013a Non Adaptative/Online

# %%
#import essential libraries

import numpy as np
import pandas as pd
import glob, os, sys, yaml
from yaml import CLoader as Loader, CDumper as Dumper
import moabb
from moabb.paradigms import P300

# %%
# Verify the epochs shape, labels, and metadata of BI2013a if wanted
# Epoch shape >>> trials X channels X time_samples

paradigm = P300()
dataset = moabb.datasets.BI2013a(NonAdaptive=True, Adaptive=False, Training=False, Online=True)
subjects = dataset.subject_list

epochs, labels, meta = paradigm.get_data(dataset=dataset, subjects = [subjects[0]], return_epochs = True)
# Out:
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 156 events (all good), 0 – 1 s (baseline off), ~9.8 MiB, data loaded,
#  'Target': 26
#  'NonTarget': 130>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 168 events (all good), 0 – 1 s (baseline off), ~10.5 MiB, data loaded,
#  'Target': 28
#  'NonTarget': 140>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 300 events (all good), 0 – 1 s (baseline off), ~18.8 MiB, data loaded,
#  'Target': 50
#  'NonTarget': 250>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 264 events (all good), 0 – 1 s (baseline off), ~16.6 MiB, data loaded,
#  'Target': 44
#  'NonTarget': 220>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 168 events (all good), 0 – 1 s (baseline off), ~10.5 MiB, data loaded,
#  'Target': 28
#  'NonTarget': 140>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 276 events (all good), 0 – 1 s (baseline off), ~17.3 MiB, data loaded,
#  'Target': 46
#  'NonTarget': 230>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 360 events (all good), 0 – 1 s (baseline off), ~22.6 MiB, data loaded,
#  'Target': 60
#  'NonTarget': 300>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# 1860 matching events found
# No baseline correction applied
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 168 events (all good), 0 – 1 s (baseline off), ~10.5 MiB, data loaded,
#  'Target': 28
#  'NonTarget': 140>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\paradigms\base.py:350: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   X = mne.concatenate_epochs(X)

# %%
# Forward your file with all .csv of the dataset

file_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files #check if you have .csv files
# Out:
# ['C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAO\\subject_24_session_01.csv']

# %%
#Calc windowlength
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
windowlength = np.diff(dataset.interval)[0]*samplingrate
windowlength

# %%
#YML creator 
#The Meta data of the Data set
#These variables and parameters should address once for each data set.  

#######################################Acquisition#######################################
filter= 'Low-Pass 83Hz (Butterworth order 4 zero phase) for downsampling'
ground='FZ'
hardware= 'g.tec EEG'
reference= 'Left ear-lobe'
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
sensors = epochs.ch_names
sensortype ='Ag/AgCl Wet electrodes'
software= 'OpenVibe'

######################################Documentation######################################
description= 'https://hal.science/hal-02103098'
doi= 'https://doi.org/10.5281/zenodo.1494163'
investigators= "Vaineau, Barachant, Andreev, Rodrigues, Cattan, Congedo"
place= 'University of Grenoble Alpes, GipsaLab France'
repository= 'https://github.com/plcrodrigues/py.BI.EEG.2013-GIPSA'
##id
condition= 'Non Adaptative - Online' 
database= 'bi2013a'  
paradigm= 'P300'
timestamp= 2013

##########################################Stim###########################################
####Labels
event_labels = dict(NonTarget=1, Target=2)
nclasses= len(event_labels.keys())
offset= 0
windowlength = 256 

#########################################Subjects########################################  
subjects=len(dataset.subject_list)
runs=1
# session = //// for bi2013a, number of sessions for the first 7 subjects
# is 8, and for the rest is only 1 (you can see this in the loop line 85)

#function of YMLcreator
def YMLcreator():
  

  d = dict(acquisition=dict
          (filter= str(filter),
          ground=str(ground),
          hardware=str(hardware),
          reference=str(reference),
          samplingrate= samplingrate,
          sensors= sensors,
          sensortype=str(sensortype),
          software=str(software)
          )
          ,documentation=dict
          (description=str(description),
          doi=str(doi),
          investigators=str(investigators),
          place=str(place),
          repository=str(repository)
          )              
          ,
          formatversion=str('0.0.1')
          ,
          id=dict
          (condition=str(condition),
          database=str(database),
          paradigm=str(paradigm),
          subject=subject,
          session=session,
          run=run,
          timestamp=timestamp,
          )
          ,stim=dict
          (labels=event_labels,
          nclasses=nclasses,
          offset=offset,
          windowlength=windowlength,
          )
          
  )
  return d  

i=-1 #don't change i

for subject in range(1,subjects+1):
    sessions = 8 if subject <= 7 else 1
    for session in range(1,sessions+1):
        i=i+1
        filepath = all_files[i]
        for run in range(1,runs+1):
            d=YMLcreator()
            
            newpath=os.path.splitext(filepath)[0] + '.yml'
            with open(newpath, 'w') as file:
              documents = yaml.dump(d, file)


              file.write("""
##############################################################################
#                     GIPSA-lab standard for EEG time series (version 0.0.1) #
#                                Authors : Pedro Rodrigues and Marco Congedo #
#                                                        November 15th, 2019 #
##############################################################################

# This format has been conceived for easily sharing EEG data in Python and 
# Julia. Each file is understood as a separate recording. Data consist of two
# files. They have the same name and extensions `npz` and `yml` (this file).

# The `npz` file typically holds the EEG data matrix, a real matrix of 
# dimension num. of samples x num. of electrodes and a vector of integer with
# the tags for stimulations, with as many entries as number of samples. The 
# tags are 0 (zero) for no stimulation and then employs the natural numbers 
# (1, 2,...) for different stimulation classes.

# The `yml` file holds all meta-data info of the recording in `yml` format. 
# It holds two fields and four dictionaries:

# FIELDS:
#
# - paradigm: (string) the experimental paradigm, e.g., P300, MI, ... 
#             for Brain Computer Interfaces experiments
#
# - formatversion: (version) version of this metadata specification

# DICTIONARIES:
#
# - acquisition: (dictionary)
#
#   - filter: (string) filter setting of the EEG acquisition machine, 
#             specifying the type and specification. Ex: "Band-pass digital 
#             filter (0.01-70Hz)"
#   - ground: (string) location of the sensor used as ground. Ex: "Fpz"
#   - reference: (string) location of the sensor used as reference for the 
#                recording. Ex: "A1"
#   - hardware: (string) the commercial name and producer of the the EEG 
#               acquisition machine. Ex: "actiCHamp, Brain Products GmbH 
#               (Germany), DC amplifiers"
#   - software: (string) software used for acquiring and storing the data. 
#               Ex: OpenViBE, INRIA (France)
#   - samplingrate:(int) sampling rate. Ex: 128
#   - sensors: (array-like of strings) location of the sensors, excluding 
#              ground and reference.
#   - sensortype: (string) type, material and product name of electrodes. 
#                 Ex: Ag/AgCl, Braincap, Brain Products GmbH (Germany)
#
# - documentation: (dictionary)
#
#   - description: (string) link to a file or website describing the dataset
#   - doi: (string) digital object identifier of the dataset's documentation
#   - repository:  (string) link to the online repository where the data can 
#                  be downloaded
#
# - id: (dictionary)
#   
#   - database: (string) name of the database
#
# - stim: (dictionary)
#
#   - labels: (dictionary) dictionary with the labels and code of the 
#             stimulations
#       - nclasses: (int) number of classes for the stimulations
#       - offset: (int) offset, given in number of samples, with respect to 
#                 stimulation samples, defining the beginning of trials
#       - windowlength: (int) size of the window, given in number of sample, 
#                       defining the duration of trials
""")

# %%
##NPZ creator

#the Structure of the Data sets 
"""
The data should be in the form of  Samples*Channels, where channels may include a column for the time,
a column for the ground, a colum for the trigger, and a colum for the target. So, you need to drop the
columns of time and ground and add the two columns of trigger and target together(If you have not already done so).
"""

timestamp_col = 0  
stim_col= 17 # Stim target

#NPZ creator

def csv2npz(filepath):

    df= pd.read_csv(filepath, header=0) # header = 0 to remove header
    df= np.array(df)
    
    # from V to µV
    raw_data = df[:, 1:-1] * 1e6  

    DATA = np.float32(raw_data)
    print(DATA.shape)

    # STIM col
    STIM = np.int16(df[:, stim_col]) 

    unique_values, counts = np.unique(STIM, return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans {filepath} : Nombre de {value} = {count}")
    
    newpath=os.path.splitext(filepath)[0] + '.npz'
    np.savez(newpath,data=DATA , stim=STIM)

for f in all_files:
    csv2npz(f)
# Out:
# (72192, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_01.csv : Nombre de 0 = 72036
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_01.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_01.csv : Nombre de 2 = 26
# (53264, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_02.csv : Nombre de 0 = 53096
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_02.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_02.csv : Nombre de 2 = 28
# (68992, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_03.csv : Nombre de 0 = 68692
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_03.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_03.csv : Nombre de 2 = 50
# (64320, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_04.csv : Nombre de 0 = 64056
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_04.csv : Nombre de 1 = 220
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_04.csv : Nombre de 2 = 44
# (49888, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_05.csv : Nombre de 0 = 49720
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_05.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_05.csv : Nombre de 2 = 28
# (63984, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_06.csv : Nombre de 0 = 63708
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_06.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_06.csv : Nombre de 2 = 46
# (75840, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_07.csv : Nombre de 0 = 75480
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_07.csv : Nombre de 1 = 300
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_07.csv : Nombre de 2 = 60
# (48576, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_08.csv : Nombre de 0 = 48408
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_08.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_01_session_08.csv : Nombre de 2 = 28
# (96752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_01.csv : Nombre de 0 = 96476
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_01.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_01.csv : Nombre de 2 = 46
# (51520, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_02.csv : Nombre de 0 = 51352
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_02.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_02.csv : Nombre de 2 = 28
# (100096, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_03.csv : Nombre de 0 = 99892
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_03.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_03.csv : Nombre de 2 = 34
# (55568, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_04.csv : Nombre de 0 = 55376
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_04.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_04.csv : Nombre de 2 = 32
# (56848, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_05.csv : Nombre de 0 = 56644
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_05.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_05.csv : Nombre de 2 = 34
# (71440, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_06.csv : Nombre de 0 = 71116
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_06.csv : Nombre de 1 = 270
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_06.csv : Nombre de 2 = 54
# (56448, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_07.csv : Nombre de 0 = 56232
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_07.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_07.csv : Nombre de 2 = 36
# (58720, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_08.csv : Nombre de 0 = 58480
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_08.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_02_session_08.csv : Nombre de 2 = 40
# (79008, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_01.csv : Nombre de 0 = 78672
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_01.csv : Nombre de 1 = 280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_01.csv : Nombre de 2 = 56
# (66608, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_02.csv : Nombre de 0 = 66332
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_02.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_02.csv : Nombre de 2 = 46
# (68768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_03.csv : Nombre de 0 = 68468
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_03.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_03.csv : Nombre de 2 = 50
# (59616, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_04.csv : Nombre de 0 = 59400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_04.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_04.csv : Nombre de 2 = 36
# (73264, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_05.csv : Nombre de 0 = 72928
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_05.csv : Nombre de 1 = 280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_05.csv : Nombre de 2 = 56
# (71328, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_06.csv : Nombre de 0 = 71028
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_06.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_06.csv : Nombre de 2 = 50
# (54800, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_07.csv : Nombre de 0 = 54596
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_07.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_07.csv : Nombre de 2 = 34
# (63824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_08.csv : Nombre de 0 = 63536
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_08.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_03_session_08.csv : Nombre de 2 = 48
# (55472, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_01.csv : Nombre de 0 = 55280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_01.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_01.csv : Nombre de 2 = 32
# (59808, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_02.csv : Nombre de 0 = 59580
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_02.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_02.csv : Nombre de 2 = 38
# (63664, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_03.csv : Nombre de 0 = 63448
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_03.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_03.csv : Nombre de 2 = 36
# (60688, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_04.csv : Nombre de 0 = 60436
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_04.csv : Nombre de 1 = 210
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_04.csv : Nombre de 2 = 42
# (78496, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_05.csv : Nombre de 0 = 78112
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_05.csv : Nombre de 1 = 320
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_05.csv : Nombre de 2 = 64
# (58960, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_06.csv : Nombre de 0 = 58732
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_06.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_06.csv : Nombre de 2 = 38
# (66480, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_07.csv : Nombre de 0 = 66180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_07.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_07.csv : Nombre de 2 = 50
# (67456, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_08.csv : Nombre de 0 = 67156
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_08.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_04_session_08.csv : Nombre de 2 = 50
# (80864, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_01.csv : Nombre de 0 = 80624
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_01.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_01.csv : Nombre de 2 = 40
# (56272, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_02.csv : Nombre de 0 = 56068
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_02.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_02.csv : Nombre de 2 = 34
# (56080, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_03.csv : Nombre de 0 = 55876
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_03.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_03.csv : Nombre de 2 = 34
# (53744, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_04.csv : Nombre de 0 = 53552
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_04.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_04.csv : Nombre de 2 = 32
# (52064, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_05.csv : Nombre de 0 = 51884
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_05.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_05.csv : Nombre de 2 = 30
# (56496, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_06.csv : Nombre de 0 = 56292
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_06.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_06.csv : Nombre de 2 = 34
# (53456, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_07.csv : Nombre de 0 = 53264
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_07.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_07.csv : Nombre de 2 = 32
# (62256, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_08.csv : Nombre de 0 = 62016
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_08.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_05_session_08.csv : Nombre de 2 = 40
# (60544, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_01.csv : Nombre de 0 = 60316
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_01.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_01.csv : Nombre de 2 = 38
# (69872, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_02.csv : Nombre de 0 = 69572
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_02.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_02.csv : Nombre de 2 = 50
# (79120, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_03.csv : Nombre de 0 = 78736
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_03.csv : Nombre de 1 = 320
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_03.csv : Nombre de 2 = 64
# (74512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_04.csv : Nombre de 0 = 74176
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_04.csv : Nombre de 1 = 280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_04.csv : Nombre de 2 = 56
# (108880, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_05.csv : Nombre de 0 = 108256
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_05.csv : Nombre de 1 = 520
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_05.csv : Nombre de 2 = 104
# (68368, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_06.csv : Nombre de 0 = 68080
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_06.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_06.csv : Nombre de 2 = 48
# (78640, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_07.csv : Nombre de 0 = 78280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_07.csv : Nombre de 1 = 300
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_07.csv : Nombre de 2 = 60
# (69584, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_08.csv : Nombre de 0 = 69248
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_08.csv : Nombre de 1 = 280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_06_session_08.csv : Nombre de 2 = 56
# (52400, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_01.csv : Nombre de 0 = 52220
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_01.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_01.csv : Nombre de 2 = 30
# (50816, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_02.csv : Nombre de 0 = 50660
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_02.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_02.csv : Nombre de 2 = 26
# (50768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_03.csv : Nombre de 0 = 50588
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_03.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_03.csv : Nombre de 2 = 30
# (50368, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_04.csv : Nombre de 0 = 50188
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_04.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_04.csv : Nombre de 2 = 30
# (56976, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_05.csv : Nombre de 0 = 56736
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_05.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_05.csv : Nombre de 2 = 40
# (54160, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_06.csv : Nombre de 0 = 53968
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_06.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_06.csv : Nombre de 2 = 32
# (53504, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_07.csv : Nombre de 0 = 53300
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_07.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_07.csv : Nombre de 2 = 34
# (50032, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_08.csv : Nombre de 0 = 49852
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_08.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_07_session_08.csv : Nombre de 2 = 30
# (72016, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_08_session_01.csv : Nombre de 0 = 71692
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_08_session_01.csv : Nombre de 1 = 270
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_08_session_01.csv : Nombre de 2 = 54
# (57760, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_09_session_01.csv : Nombre de 0 = 57580
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_09_session_01.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_09_session_01.csv : Nombre de 2 = 30
# (71072, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_10_session_01.csv : Nombre de 0 = 70784
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_10_session_01.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_10_session_01.csv : Nombre de 2 = 48
# (59488, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_11_session_01.csv : Nombre de 0 = 59260
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_11_session_01.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_11_session_01.csv : Nombre de 2 = 38
# (65344, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_12_session_01.csv : Nombre de 0 = 65068
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_12_session_01.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_12_session_01.csv : Nombre de 2 = 46
# (84048, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_13_session_01.csv : Nombre de 0 = 83640
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_13_session_01.csv : Nombre de 1 = 340
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_13_session_01.csv : Nombre de 2 = 68
# (51920, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_14_session_01.csv : Nombre de 0 = 51728
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_14_session_01.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_14_session_01.csv : Nombre de 2 = 32
# (50336, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_15_session_01.csv : Nombre de 0 = 50168
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_15_session_01.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_15_session_01.csv : Nombre de 2 = 28
# (63152, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_16_session_01.csv : Nombre de 0 = 62972
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_16_session_01.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_16_session_01.csv : Nombre de 2 = 30
# (56912, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_17_session_01.csv : Nombre de 0 = 56684
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_17_session_01.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_17_session_01.csv : Nombre de 2 = 38
# (47584, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_18_session_01.csv : Nombre de 0 = 47428
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_18_session_01.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_18_session_01.csv : Nombre de 2 = 26
# (99840, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_19_session_01.csv : Nombre de 0 = 99468
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_19_session_01.csv : Nombre de 1 = 310
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_19_session_01.csv : Nombre de 2 = 62
# (67056, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_20_session_01.csv : Nombre de 0 = 66768
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_20_session_01.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_20_session_01.csv : Nombre de 2 = 48
# (47968, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_21_session_01.csv : Nombre de 0 = 47812
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_21_session_01.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_21_session_01.csv : Nombre de 2 = 26
# (69392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_22_session_01.csv : Nombre de 0 = 69092
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_22_session_01.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_22_session_01.csv : Nombre de 2 = 50
# (94272, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_23_session_01.csv : Nombre de 0 = 93780
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_23_session_01.csv : Nombre de 1 = 410
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_23_session_01.csv : Nombre de 2 = 82
# (54512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_24_session_01.csv : Nombre de 0 = 54308
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_24_session_01.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAO\subject_24_session_01.csv : Nombre de 2 = 34
