# %% [markdown]
# MOABB to NY format
#
# .CSV to NY
#
# this code convert the data sets in .CSV format to NY format which it can be easily read in Julia and Python.
#
# The .npz file holds the data and the stimulation vector while the .yml file holds the metadata.
#
# It has been specifically conceived for BCI data.
#
# This script is for BI2013a Adaptative/Training

# %%
#import essential libraries

import numpy as np
import pandas as pd
import glob, os, sys, yaml
from yaml import CLoader as Loader, CDumper as Dumper
import moabb
from moabb.paradigms import P300

# %%
# Verify the epochs shape, labels, and metadata of BI2013a if wanted
# Epoch shape >>> trials X channels X time_samples

paradigm = P300()
dataset = moabb.datasets.BI2013a(NonAdaptive=False, Adaptive=True, Training=True, Online=False)
subjects = dataset.subject_list

epochs, labels, meta = paradigm.get_data(dataset=dataset, subjects = [subjects[0]], return_epochs = True)
# Out:
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# 3840 matching events found
# No baseline correction applied
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\paradigms\base.py:350: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   X = mne.concatenate_epochs(X)

# %%
# Forward your file with all .csv of the dataset

file_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files #check if you have .csv files
# Out:
# ['C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AT\\subject_24_session_01.csv']

# %%
#Calc windowlength
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
windowlength = np.diff(dataset.interval)[0]*samplingrate
windowlength
# Out:
# 256

# %%
#YML creator 
#The Meta data of the Data set
#These variables and parameters should address once for each data set.  

#######################################Acquisition#######################################
filter= 'Low-Pass 83Hz (Butterworth order 4 zero phase) for downsampling'
ground='FZ'
hardware= 'g.tec EEG'
reference= 'Left ear-lobe'
samplingrate= 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
sensors = epochs.ch_names
sensortype ='Ag/AgCl Wet electrodes'
software= 'OpenVibe'

######################################Documentation######################################
description= 'https://hal.science/hal-02103098'
doi= 'https://doi.org/10.5281/zenodo.1494163'
investigators= "Vaineau, Barachant, Andreev, Rodrigues, Cattan, Congedo"
place= 'University of Grenoble Alpes, GipsaLab France'
repository= 'https://github.com/plcrodrigues/py.BI.EEG.2013-GIPSA'
##id
condition= 'Adaptative - Training' 
database= 'bi2013a'  
paradigm= 'P300'
timestamp= 2013

##########################################Stim###########################################
####Labels
event_labels = dict(NonTarget=1, Target=2)
nclasses= len(event_labels.keys())
offset= 0
windowlength = 256 

#########################################Subjects########################################  
subjects=len(dataset.subject_list)
runs=1
# session = //// for bi2013a, number of sessions for the first 7 subjects
# is 8, and for the rest is only 1 (you can see this in the loop line 85)

#function of YMLcreator
def YMLcreator():
  

  d = dict(acquisition=dict
          (filter= str(filter),
          ground=str(ground),
          hardware=str(hardware),
          reference=str(reference),
          samplingrate= samplingrate,
          sensors= sensors,
          sensortype=str(sensortype),
          software=str(software)
          )
          ,documentation=dict
          (description=str(description),
          doi=str(doi),
          investigators=str(investigators),
          place=str(place),
          repository=str(repository)
          )              
          ,
          formatversion=str('0.0.1')
          ,
          id=dict
          (condition=str(condition),
          database=str(database),
          paradigm=str(paradigm),
          subject=subject,
          session=session,
          run=run,
          timestamp=timestamp,
          )
          ,stim=dict
          (labels=event_labels,
          nclasses=nclasses,
          offset=offset,
          windowlength=windowlength,
          )
          
  )
  return d  

i=-1 #don't change i

for subject in range(1,subjects+1):
    sessions = 8 if subject <= 7 else 1
    for session in range(1,sessions+1):
        i=i+1
        filepath = all_files[i]
        for run in range(1,runs+1):
            d=YMLcreator()
            
            newpath=os.path.splitext(filepath)[0] + '.yml'
            with open(newpath, 'w') as file:
              documents = yaml.dump(d, file)


              file.write("""
##############################################################################
#                     GIPSA-lab standard for EEG time series (version 0.0.1) #
#                                Authors : Pedro Rodrigues and Marco Congedo #
#                                                        November 15th, 2019 #
##############################################################################

# This format has been conceived for easily sharing EEG data in Python and 
# Julia. Each file is understood as a separate recording. Data consist of two
# files. They have the same name and extensions `npz` and `yml` (this file).

# The `npz` file typically holds the EEG data matrix, a real matrix of 
# dimension num. of samples x num. of electrodes and a vector of integer with
# the tags for stimulations, with as many entries as number of samples. The 
# tags are 0 (zero) for no stimulation and then employs the natural numbers 
# (1, 2,...) for different stimulation classes.

# The `yml` file holds all meta-data info of the recording in `yml` format. 
# It holds two fields and four dictionaries:

# FIELDS:
#
# - paradigm: (string) the experimental paradigm, e.g., P300, MI, ... 
#             for Brain Computer Interfaces experiments
#
# - formatversion: (version) version of this metadata specification

# DICTIONARIES:
#
# - acquisition: (dictionary)
#
#   - filter: (string) filter setting of the EEG acquisition machine, 
#             specifying the type and specification. Ex: "Band-pass digital 
#             filter (0.01-70Hz)"
#   - ground: (string) location of the sensor used as ground. Ex: "Fpz"
#   - reference: (string) location of the sensor used as reference for the 
#                recording. Ex: "A1"
#   - hardware: (string) the commercial name and producer of the the EEG 
#               acquisition machine. Ex: "actiCHamp, Brain Products GmbH 
#               (Germany), DC amplifiers"
#   - software: (string) software used for acquiring and storing the data. 
#               Ex: OpenViBE, INRIA (France)
#   - samplingrate:(int) sampling rate. Ex: 128
#   - sensors: (array-like of strings) location of the sensors, excluding 
#              ground and reference.
#   - sensortype: (string) type, material and product name of electrodes. 
#                 Ex: Ag/AgCl, Braincap, Brain Products GmbH (Germany)
#
# - documentation: (dictionary)
#
#   - description: (string) link to a file or website describing the dataset
#   - doi: (string) digital object identifier of the dataset's documentation
#   - repository:  (string) link to the online repository where the data can 
#                  be downloaded
#
# - id: (dictionary)
#   
#   - database: (string) name of the database
#
# - stim: (dictionary)
#
#   - labels: (dictionary) dictionary with the labels and code of the 
#             stimulations
#       - nclasses: (int) number of classes for the stimulations
#       - offset: (int) offset, given in number of samples, with respect to 
#                 stimulation samples, defining the beginning of trials
#       - windowlength: (int) size of the window, given in number of sample, 
#                       defining the duration of trials
""")

# %%
##NPZ creator

#the Structure of the Data sets 
"""
The data should be in the form of  Samples*Channels, where channels may include a column for the time,
a column for the ground, a colum for the trigger, and a colum for the target. So, you need to drop the
columns of time and ground and add the two columns of trigger and target together(If you have not already done so).
"""

timestamp_col = 0  
stim_col= 17 # Stim target

#NPZ creator

def csv2npz(filepath):

    df= pd.read_csv(filepath, header=0) # header = 0 to remove header
    df= np.array(df)
    
    # from V to µV
    raw_data = df[:, 1:-1] * 1e6  

    DATA = np.float32(raw_data)
    print(DATA.shape)

    # STIM col
    STIM = np.int16(df[:, stim_col]) 

    unique_values, counts = np.unique(STIM, return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans {filepath} : Nombre de {value} = {count}")
    
    newpath=os.path.splitext(filepath)[0] + '.npz'
    np.savez(newpath,data=DATA , stim=STIM)

for f in all_files:
    csv2npz(f)
# Out:
# (79616, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_01.csv : Nombre de 0 = 79136
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_01.csv : Nombre de 2 = 80
# (66448, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_02.csv : Nombre de 0 = 65968
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_02.csv : Nombre de 2 = 80
# (65888, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_03.csv : Nombre de 0 = 65408
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_03.csv : Nombre de 2 = 80
# (73296, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_04.csv : Nombre de 0 = 72816
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_04.csv : Nombre de 2 = 80
# (66752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_05.csv : Nombre de 0 = 66272
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_05.csv : Nombre de 2 = 80
# (66448, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_06.csv : Nombre de 0 = 65968
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_06.csv : Nombre de 2 = 80
# (63536, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_07.csv : Nombre de 0 = 63056
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_07.csv : Nombre de 2 = 80
# (64912, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_08.csv : Nombre de 0 = 64432
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_01_session_08.csv : Nombre de 2 = 80
# (74544, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_01.csv : Nombre de 0 = 74064
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_01.csv : Nombre de 2 = 80
# (66240, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_02.csv : Nombre de 0 = 65760
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_02.csv : Nombre de 2 = 80
# (68048, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_03.csv : Nombre de 0 = 67568
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_03.csv : Nombre de 2 = 80
# (71152, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_04.csv : Nombre de 0 = 70672
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_04.csv : Nombre de 2 = 80
# (72336, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_05.csv : Nombre de 0 = 71856
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_05.csv : Nombre de 2 = 80
# (66656, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_06.csv : Nombre de 0 = 66176
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_06.csv : Nombre de 2 = 80
# (68960, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_07.csv : Nombre de 0 = 68480
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_07.csv : Nombre de 2 = 80
# (70624, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_08.csv : Nombre de 0 = 70144
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_02_session_08.csv : Nombre de 2 = 80
# (74752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_01.csv : Nombre de 0 = 74272
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_01.csv : Nombre de 2 = 80
# (73216, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_02.csv : Nombre de 0 = 72736
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_02.csv : Nombre de 2 = 80
# (70640, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_03.csv : Nombre de 0 = 70160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_03.csv : Nombre de 2 = 80
# (64800, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_04.csv : Nombre de 0 = 64320
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_04.csv : Nombre de 2 = 80
# (66944, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_05.csv : Nombre de 0 = 66464
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_05.csv : Nombre de 2 = 80
# (69104, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_06.csv : Nombre de 0 = 68624
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_06.csv : Nombre de 2 = 80
# (68096, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_07.csv : Nombre de 0 = 67616
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_07.csv : Nombre de 2 = 80
# (68352, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_08.csv : Nombre de 0 = 67872
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_03_session_08.csv : Nombre de 2 = 80
# (71504, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_01.csv : Nombre de 0 = 71024
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_01.csv : Nombre de 2 = 80
# (68048, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_02.csv : Nombre de 0 = 67568
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_02.csv : Nombre de 2 = 80
# (68192, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_03.csv : Nombre de 0 = 67712
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_03.csv : Nombre de 2 = 80
# (67168, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_04.csv : Nombre de 0 = 66688
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_04.csv : Nombre de 2 = 80
# (68096, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_05.csv : Nombre de 0 = 67616
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_05.csv : Nombre de 2 = 80
# (65392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_06.csv : Nombre de 0 = 64912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_06.csv : Nombre de 2 = 80
# (69072, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_07.csv : Nombre de 0 = 68592
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_07.csv : Nombre de 2 = 80
# (69648, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_08.csv : Nombre de 0 = 69168
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_04_session_08.csv : Nombre de 2 = 80
# (69472, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_01.csv : Nombre de 0 = 68992
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_01.csv : Nombre de 2 = 80
# (70160, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_02.csv : Nombre de 0 = 69680
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_02.csv : Nombre de 2 = 80
# (69568, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_03.csv : Nombre de 0 = 69088
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_03.csv : Nombre de 2 = 80
# (68064, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_04.csv : Nombre de 0 = 67584
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_04.csv : Nombre de 2 = 80
# (71088, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_05.csv : Nombre de 0 = 70608
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_05.csv : Nombre de 2 = 80
# (67824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_06.csv : Nombre de 0 = 67344
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_06.csv : Nombre de 2 = 80
# (66928, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_07.csv : Nombre de 0 = 66448
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_07.csv : Nombre de 2 = 80
# (67680, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_08.csv : Nombre de 0 = 67200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_05_session_08.csv : Nombre de 2 = 80
# (68944, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_01.csv : Nombre de 0 = 68464
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_01.csv : Nombre de 2 = 80
# (66256, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_02.csv : Nombre de 0 = 65776
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_02.csv : Nombre de 2 = 80
# (67424, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_03.csv : Nombre de 0 = 66944
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_03.csv : Nombre de 2 = 80
# (68096, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_04.csv : Nombre de 0 = 67616
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_04.csv : Nombre de 2 = 80
# (66656, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_05.csv : Nombre de 0 = 66176
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_05.csv : Nombre de 2 = 80
# (69968, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_06.csv : Nombre de 0 = 69488
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_06.csv : Nombre de 2 = 80
# (71872, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_07.csv : Nombre de 0 = 71392
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_07.csv : Nombre de 2 = 80
# (67088, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_08.csv : Nombre de 0 = 66608
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_06_session_08.csv : Nombre de 2 = 80
# (67872, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_01.csv : Nombre de 0 = 67392
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_01.csv : Nombre de 2 = 80
# (65968, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_02.csv : Nombre de 0 = 65488
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_02.csv : Nombre de 2 = 80
# (68256, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_03.csv : Nombre de 0 = 67776
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_03.csv : Nombre de 2 = 80
# (68176, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_04.csv : Nombre de 0 = 67696
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_04.csv : Nombre de 2 = 80
# (64048, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_05.csv : Nombre de 0 = 63568
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_05.csv : Nombre de 2 = 80
# (68256, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_06.csv : Nombre de 0 = 67776
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_06.csv : Nombre de 2 = 80
# (70512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_07.csv : Nombre de 0 = 70032
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_07.csv : Nombre de 2 = 80
# (65200, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_08.csv : Nombre de 0 = 64720
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_07_session_08.csv : Nombre de 2 = 80
# (71984, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_08_session_01.csv : Nombre de 0 = 71504
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_08_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_08_session_01.csv : Nombre de 2 = 80
# (81568, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_09_session_01.csv : Nombre de 0 = 81088
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_09_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_09_session_01.csv : Nombre de 2 = 80
# (69664, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_10_session_01.csv : Nombre de 0 = 69184
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_10_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_10_session_01.csv : Nombre de 2 = 80
# (68800, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_11_session_01.csv : Nombre de 0 = 68320
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_11_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_11_session_01.csv : Nombre de 2 = 80
# (69792, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_12_session_01.csv : Nombre de 0 = 69312
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_12_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_12_session_01.csv : Nombre de 2 = 80
# (64000, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_13_session_01.csv : Nombre de 0 = 63520
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_13_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_13_session_01.csv : Nombre de 2 = 80
# (71360, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_14_session_01.csv : Nombre de 0 = 70880
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_14_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_14_session_01.csv : Nombre de 2 = 80
# (69488, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_15_session_01.csv : Nombre de 0 = 69008
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_15_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_15_session_01.csv : Nombre de 2 = 80
# (65712, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_16_session_01.csv : Nombre de 0 = 65232
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_16_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_16_session_01.csv : Nombre de 2 = 80
# (69344, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_17_session_01.csv : Nombre de 0 = 68864
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_17_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_17_session_01.csv : Nombre de 2 = 80
# (65920, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_18_session_01.csv : Nombre de 0 = 65440
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_18_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_18_session_01.csv : Nombre de 2 = 80
# (68624, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_19_session_01.csv : Nombre de 0 = 68144
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_19_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_19_session_01.csv : Nombre de 2 = 80
# (69840, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_20_session_01.csv : Nombre de 0 = 69360
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_20_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_20_session_01.csv : Nombre de 2 = 80
# (72032, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_21_session_01.csv : Nombre de 0 = 71552
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_21_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_21_session_01.csv : Nombre de 2 = 80
# (69712, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_22_session_01.csv : Nombre de 0 = 69232
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_22_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_22_session_01.csv : Nombre de 2 = 80
# (71424, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_23_session_01.csv : Nombre de 0 = 70944
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_23_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_23_session_01.csv : Nombre de 2 = 80
# (67520, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_24_session_01.csv : Nombre de 0 = 67040
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_24_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AT\subject_24_session_01.csv : Nombre de 2 = 80
