# %% [markdown]
# MOABB to NY format
#
# .CSV to NY
#
# this code convert the data sets in .CSV format to NY format which it can be easily read in Julia and Python.
#
# The .npz file holds the data and the stimulation vector while the .yml file holds the metadata.
#
# It has been specifically conceived for BCI data.
#
# This script is for BI2013a Adaptative/Online

# %%
#import essential libraries

import numpy as np
import pandas as pd
import glob, os, sys, yaml
from yaml import CLoader as Loader, CDumper as Dumper
import moabb
from moabb.paradigms import P300

# %%
# Verify the epochs shape, labels, and metadata of BI2013a if wanted
# Epoch shape >>> trials X channels X time_samples

paradigm = P300()
dataset = moabb.datasets.BI2013a(NonAdaptive=False, Adaptive=True, Training=False, Online=True)
subjects = dataset.subject_list

epochs, labels, meta = paradigm.get_data(dataset=dataset, subjects = [subjects[0]], return_epochs = True)
# Out:
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 192 events (all good), 0 – 1 s (baseline off), ~12.1 MiB, data loaded,
#  'Target': 32
#  'NonTarget': 160>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 168 events (all good), 0 – 1 s (baseline off), ~10.5 MiB, data loaded,
#  'Target': 28
#  'NonTarget': 140>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 156 events (all good), 0 – 1 s (baseline off), ~9.8 MiB, data loaded,
#  'Target': 26
#  'NonTarget': 130>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 144 events (all good), 0 – 1 s (baseline off), ~9.0 MiB, data loaded,
#  'Target': 24
#  'NonTarget': 120>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 204 events (all good), 0 – 1 s (baseline off), ~12.8 MiB, data loaded,
#  'Target': 34
#  'NonTarget': 170>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 144 events (all good), 0 – 1 s (baseline off), ~9.0 MiB, data loaded,
#  'Target': 24
#  'NonTarget': 120>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 192 events (all good), 0 – 1 s (baseline off), ~12.1 MiB, data loaded,
#  'Target': 32
#  'NonTarget': 160>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 156 events (all good), 0 – 1 s (baseline off), ~9.8 MiB, data loaded,
#  'Target': 26
#  'NonTarget': 130>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# 1356 matching events found
# No baseline correction applied
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\paradigms\base.py:350: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   X = mne.concatenate_epochs(X)

# %%
epochs.ch_names
# Out:
# ['Fp1',
#  'Fp2',
#  'F5',
#  'AFz',
#  'F6',
#  'T7',
#  'Cz',
#  'T8',
#  'P7',
#  'P3',
#  'Pz',
#  'P4',
#  'P8',
#  'O1',
#  'Oz',
#  'O2']

# %%
event_labels = dataset.event_id
event_labels
# Out:
# {'Target': 33285, 'NonTarget': 33286}

# %%
# Forward your file with all .csv of the dataset

file_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files #check if you have .csv files
# Out:
# ['C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO\\subject_24_session_01.csv']

# %%
#Calc windowlength
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
windowlength = np.diff(dataset.interval)[0]*samplingrate
windowlength
# Out:
# 256

# %%
#YML creator 
#The Meta data of the Data set
#These variables and parameters should address once for each data set.  

#######################################Acquisition#######################################
filter= 'Low-Pass 83Hz (Butterworth order 4 zero phase) for downsampling'
ground='FZ'
hardware= 'g.tec EEG'
reference= 'Left ear-lobe'
samplingrate= 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
sensors = epochs.ch_names
sensortype ='Ag/AgCl Wet electrodes'
software= 'OpenVibe'

######################################Documentation######################################
description= 'https://hal.science/hal-02103098'
doi= 'https://doi.org/10.5281/zenodo.1494163'
investigators= "Vaineau, Barachant, Andreev, Rodrigues, Cattan, Congedo"
place= 'University of Grenoble Alpes, GipsaLab France'
repository= 'https://github.com/plcrodrigues/py.BI.EEG.2013-GIPSA'
##id
condition= 'Adaptative - Online' 
database= 'bi2013a'  
paradigm= 'P300'
timestamp= 2013

##########################################Stim###########################################
####Labels
event_labels = dict(NonTarget=1, Target=2)
nclasses= len(event_labels.keys())
offset= 0
windowlength = 256 

#########################################Subjects########################################  
subjects=len(dataset.subject_list)
runs=1
# session = //// for bi2013a, number of sessions for the first 7 subjects
# is 8, and for the rest is only 1 (you can see this in the loop line 85)

#function of YMLcreator
def YMLcreator():
  

  d = dict(acquisition=dict
          (filter= str(filter),
          ground=str(ground),
          hardware=str(hardware),
          reference=str(reference),
          samplingrate= samplingrate,
          sensors= sensors,
          sensortype=str(sensortype),
          software=str(software)
          )
          ,documentation=dict
          (description=str(description),
          doi=str(doi),
          investigators=str(investigators),
          place=str(place),
          repository=str(repository)
          )              
          ,
          formatversion=str('0.0.1')
          ,
          id=dict
          (condition=str(condition),
          database=str(database),
          paradigm=str(paradigm),
          subject=subject,
          session=session,
          run=run,
          timestamp=timestamp,
          )
          ,stim=dict
          (labels=event_labels,
          nclasses=nclasses,
          offset=offset,
          windowlength=windowlength,
          )
          
  )
  return d  

i=-1 #don't change i

for subject in range(1,subjects+1):
    sessions = 8 if subject <= 7 else 1
    for session in range(1,sessions+1):
        i=i+1
        filepath = all_files[i]
        for run in range(1,runs+1):
            d=YMLcreator()
            
            newpath=os.path.splitext(filepath)[0] + '.yml'
            with open(newpath, 'w') as file:
              documents = yaml.dump(d, file)


              file.write("""
##############################################################################
#                     GIPSA-lab standard for EEG time series (version 0.0.1) #
#                                Authors : Pedro Rodrigues and Marco Congedo #
#                                                        November 15th, 2019 #
##############################################################################

# This format has been conceived for easily sharing EEG data in Python and 
# Julia. Each file is understood as a separate recording. Data consist of two
# files. They have the same name and extensions `npz` and `yml` (this file).

# The `npz` file typically holds the EEG data matrix, a real matrix of 
# dimension num. of samples x num. of electrodes and a vector of integer with
# the tags for stimulations, with as many entries as number of samples. The 
# tags are 0 (zero) for no stimulation and then employs the natural numbers 
# (1, 2,...) for different stimulation classes.

# The `yml` file holds all meta-data info of the recording in `yml` format. 
# It holds two fields and four dictionaries:

# FIELDS:
#
# - paradigm: (string) the experimental paradigm, e.g., P300, MI, ... 
#             for Brain Computer Interfaces experiments
#
# - formatversion: (version) version of this metadata specification

# DICTIONARIES:
#
# - acquisition: (dictionary)
#
#   - filter: (string) filter setting of the EEG acquisition machine, 
#             specifying the type and specification. Ex: "Band-pass digital 
#             filter (0.01-70Hz)"
#   - ground: (string) location of the sensor used as ground. Ex: "Fpz"
#   - reference: (string) location of the sensor used as reference for the 
#                recording. Ex: "A1"
#   - hardware: (string) the commercial name and producer of the the EEG 
#               acquisition machine. Ex: "actiCHamp, Brain Products GmbH 
#               (Germany), DC amplifiers"
#   - software: (string) software used for acquiring and storing the data. 
#               Ex: OpenViBE, INRIA (France)
#   - samplingrate:(int) sampling rate. Ex: 128
#   - sensors: (array-like of strings) location of the sensors, excluding 
#              ground and reference.
#   - sensortype: (string) type, material and product name of electrodes. 
#                 Ex: Ag/AgCl, Braincap, Brain Products GmbH (Germany)
#
# - documentation: (dictionary)
#
#   - description: (string) link to a file or website describing the dataset
#   - doi: (string) digital object identifier of the dataset's documentation
#   - repository:  (string) link to the online repository where the data can 
#                  be downloaded
#
# - id: (dictionary)
#   
#   - database: (string) name of the database
#
# - stim: (dictionary)
#
#   - labels: (dictionary) dictionary with the labels and code of the 
#             stimulations
#       - nclasses: (int) number of classes for the stimulations
#       - offset: (int) offset, given in number of samples, with respect to 
#                 stimulation samples, defining the beginning of trials
#       - windowlength: (int) size of the window, given in number of sample, 
#                       defining the duration of trials
""")

# %%
##NPZ creator

#the Structure of the Data sets 
"""
The data should be in the form of  Samples*Channels, where channels may include a column for the time,
a column for the ground, a colum for the trigger, and a colum for the target. So, you need to drop the
columns of time and ground and add the two columns of trigger and target together(If you have not already done so).
"""

timestamp_col = 0  
stim_col= 17 # Stim target

#NPZ creator

def csv2npz(filepath):

    df= pd.read_csv(filepath, header=0) # header = 0 to remove header
    df= np.array(df)
    
    # from V to µV
    raw_data = df[:, 1:-1] * 1e6  

    DATA = np.float32(raw_data)
    print(DATA.shape)

    # STIM col
    STIM = np.int16(df[:, stim_col]) 

    unique_values, counts = np.unique(STIM, return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans {filepath} : Nombre de {value} = {count}")
    
    newpath=os.path.splitext(filepath)[0] + '.npz'
    np.savez(newpath,data=DATA , stim=STIM)

for f in all_files:
    csv2npz(f)
# Out:
# (62592, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_01.csv : Nombre de 0 = 62400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_01.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_01.csv : Nombre de 2 = 32
# (52320, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_02.csv : Nombre de 0 = 52152
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_02.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_02.csv : Nombre de 2 = 28
# (50592, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_03.csv : Nombre de 0 = 50436
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_03.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_03.csv : Nombre de 2 = 26
# (48752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_04.csv : Nombre de 0 = 48608
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_04.csv : Nombre de 1 = 120
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_04.csv : Nombre de 2 = 24
# (57024, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_05.csv : Nombre de 0 = 56820
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_05.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_05.csv : Nombre de 2 = 34
# (51264, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_06.csv : Nombre de 0 = 51120
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_06.csv : Nombre de 1 = 120
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_06.csv : Nombre de 2 = 24
# (52288, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_07.csv : Nombre de 0 = 52096
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_07.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_07.csv : Nombre de 2 = 32
# (47280, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_08.csv : Nombre de 0 = 47124
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_08.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_01_session_08.csv : Nombre de 2 = 26
# (69424, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_01.csv : Nombre de 0 = 69148
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_01.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_01.csv : Nombre de 2 = 46
# (60672, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_02.csv : Nombre de 0 = 60432
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_02.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_02.csv : Nombre de 2 = 40
# (54416, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_03.csv : Nombre de 0 = 54236
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_03.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_03.csv : Nombre de 2 = 30
# (56720, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_04.csv : Nombre de 0 = 56540
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_04.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_04.csv : Nombre de 2 = 30
# (56784, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_05.csv : Nombre de 0 = 56568
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_05.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_05.csv : Nombre de 2 = 36
# (66512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_06.csv : Nombre de 0 = 66224
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_06.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_06.csv : Nombre de 2 = 48
# (51056, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_07.csv : Nombre de 0 = 50876
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_07.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_07.csv : Nombre de 2 = 30
# (52624, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_08.csv : Nombre de 0 = 52444
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_08.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_02_session_08.csv : Nombre de 2 = 30
# (68176, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_01.csv : Nombre de 0 = 67912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_01.csv : Nombre de 1 = 220
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_01.csv : Nombre de 2 = 44
# (59488, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_02.csv : Nombre de 0 = 59260
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_02.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_02.csv : Nombre de 2 = 38
# (58576, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_03.csv : Nombre de 0 = 58372
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_03.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_03.csv : Nombre de 2 = 34
# (55264, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_04.csv : Nombre de 0 = 55072
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_04.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_04.csv : Nombre de 2 = 32
# (50768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_05.csv : Nombre de 0 = 50588
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_05.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_05.csv : Nombre de 2 = 30
# (48608, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_06.csv : Nombre de 0 = 48452
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_06.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_06.csv : Nombre de 2 = 26
# (50544, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_07.csv : Nombre de 0 = 50364
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_07.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_07.csv : Nombre de 2 = 30
# (61568, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_08.csv : Nombre de 0 = 61304
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_08.csv : Nombre de 1 = 220
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_03_session_08.csv : Nombre de 2 = 44
# (55072, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_01.csv : Nombre de 0 = 54892
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_01.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_01.csv : Nombre de 2 = 30
# (66864, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_02.csv : Nombre de 0 = 66588
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_02.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_02.csv : Nombre de 2 = 46
# (59456, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_03.csv : Nombre de 0 = 59240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_03.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_03.csv : Nombre de 2 = 36
# (62544, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_04.csv : Nombre de 0 = 62292
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_04.csv : Nombre de 1 = 210
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_04.csv : Nombre de 2 = 42
# (60144, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_05.csv : Nombre de 0 = 59916
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_05.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_05.csv : Nombre de 2 = 38
# (50704, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_06.csv : Nombre de 0 = 50524
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_06.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_06.csv : Nombre de 2 = 30
# (53328, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_07.csv : Nombre de 0 = 53124
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_07.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_07.csv : Nombre de 2 = 34
# (64704, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_08.csv : Nombre de 0 = 64476
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_08.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_04_session_08.csv : Nombre de 2 = 38
# (61200, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_01.csv : Nombre de 0 = 60996
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_01.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_01.csv : Nombre de 2 = 34
# (55248, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_02.csv : Nombre de 0 = 55056
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_02.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_02.csv : Nombre de 2 = 32
# (69200, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_03.csv : Nombre de 0 = 68912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_03.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_03.csv : Nombre de 2 = 48
# (55616, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_04.csv : Nombre de 0 = 55400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_04.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_04.csv : Nombre de 2 = 36
# (50176, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_05.csv : Nombre de 0 = 50008
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_05.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_05.csv : Nombre de 2 = 28
# (55712, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_06.csv : Nombre de 0 = 55508
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_06.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_06.csv : Nombre de 2 = 34
# (51024, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_07.csv : Nombre de 0 = 50856
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_07.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_07.csv : Nombre de 2 = 28
# (55440, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_08.csv : Nombre de 0 = 55248
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_08.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_05_session_08.csv : Nombre de 2 = 32
# (66752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_01.csv : Nombre de 0 = 66464
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_01.csv : Nombre de 1 = 240
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_01.csv : Nombre de 2 = 48
# (62288, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_02.csv : Nombre de 0 = 62036
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_02.csv : Nombre de 1 = 210
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_02.csv : Nombre de 2 = 42
# (54080, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_03.csv : Nombre de 0 = 53900
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_03.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_03.csv : Nombre de 2 = 30
# (64336, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_04.csv : Nombre de 0 = 64060
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_04.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_04.csv : Nombre de 2 = 46
# (58912, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_05.csv : Nombre de 0 = 58696
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_05.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_05.csv : Nombre de 2 = 36
# (51728, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_06.csv : Nombre de 0 = 51536
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_06.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_06.csv : Nombre de 2 = 32
# (56240, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_07.csv : Nombre de 0 = 56024
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_07.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_07.csv : Nombre de 2 = 36
# (69360, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_08.csv : Nombre de 0 = 69036
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_08.csv : Nombre de 1 = 270
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_06_session_08.csv : Nombre de 2 = 54
# (86496, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_01.csv : Nombre de 0 = 86292
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_01.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_01.csv : Nombre de 2 = 34
# (51824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_02.csv : Nombre de 0 = 51656
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_02.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_02.csv : Nombre de 2 = 28
# (49504, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_03.csv : Nombre de 0 = 49336
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_03.csv : Nombre de 1 = 140
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_03.csv : Nombre de 2 = 28
# (50704, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_04.csv : Nombre de 0 = 50524
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_04.csv : Nombre de 1 = 150
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_04.csv : Nombre de 2 = 30
# (45968, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_05.csv : Nombre de 0 = 45812
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_05.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_05.csv : Nombre de 2 = 26
# (47184, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_06.csv : Nombre de 0 = 47028
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_06.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_06.csv : Nombre de 2 = 26
# (46864, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_07.csv : Nombre de 0 = 46708
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_07.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_07.csv : Nombre de 2 = 26
# (46768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_08.csv : Nombre de 0 = 46612
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_08.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_07_session_08.csv : Nombre de 2 = 26
# (60688, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_08_session_01.csv : Nombre de 0 = 60448
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_08_session_01.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_08_session_01.csv : Nombre de 2 = 40
# (58176, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_09_session_01.csv : Nombre de 0 = 57960
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_09_session_01.csv : Nombre de 1 = 180
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_09_session_01.csv : Nombre de 2 = 36
# (70768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_10_session_01.csv : Nombre de 0 = 70432
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_10_session_01.csv : Nombre de 1 = 280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_10_session_01.csv : Nombre de 2 = 56
# (73616, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_11_session_01.csv : Nombre de 0 = 73292
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_11_session_01.csv : Nombre de 1 = 270
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_11_session_01.csv : Nombre de 2 = 54
# (72528, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_12_session_01.csv : Nombre de 0 = 72204
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_12_session_01.csv : Nombre de 1 = 270
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_12_session_01.csv : Nombre de 2 = 54
# (61232, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_13_session_01.csv : Nombre de 0 = 60980
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_13_session_01.csv : Nombre de 1 = 210
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_13_session_01.csv : Nombre de 2 = 42
# (53728, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_14_session_01.csv : Nombre de 0 = 53536
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_14_session_01.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_14_session_01.csv : Nombre de 2 = 32
# (48528, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_15_session_01.csv : Nombre de 0 = 48372
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_15_session_01.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_15_session_01.csv : Nombre de 2 = 26
# (54528, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_16_session_01.csv : Nombre de 0 = 54324
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_16_session_01.csv : Nombre de 1 = 170
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_16_session_01.csv : Nombre de 2 = 34
# (63376, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_17_session_01.csv : Nombre de 0 = 63100
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_17_session_01.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_17_session_01.csv : Nombre de 2 = 46
# (57952, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_18_session_01.csv : Nombre de 0 = 57796
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_18_session_01.csv : Nombre de 1 = 130
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_18_session_01.csv : Nombre de 2 = 26
# (57936, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_19_session_01.csv : Nombre de 0 = 57708
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_19_session_01.csv : Nombre de 1 = 190
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_19_session_01.csv : Nombre de 2 = 38
# (59504, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_20_session_01.csv : Nombre de 0 = 59264
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_20_session_01.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_20_session_01.csv : Nombre de 2 = 40
# (52912, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_21_session_01.csv : Nombre de 0 = 52720
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_21_session_01.csv : Nombre de 1 = 160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_21_session_01.csv : Nombre de 2 = 32
# (62512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_22_session_01.csv : Nombre de 0 = 62272
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_22_session_01.csv : Nombre de 1 = 200
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_22_session_01.csv : Nombre de 2 = 40
# (66832, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_23_session_01.csv : Nombre de 0 = 66532
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_23_session_01.csv : Nombre de 1 = 250
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_23_session_01.csv : Nombre de 2 = 50
# (92096, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_24_session_01.csv : Nombre de 0 = 91820
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_24_session_01.csv : Nombre de 1 = 230
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-AO\subject_24_session_01.csv : Nombre de 2 = 46
