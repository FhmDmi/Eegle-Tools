# %% [markdown]
# MOABB to NY format
#
# .CSV to NY
#
# this code convert the data sets in .CSV format to NY format which it can be easily read in Julia and Python.
#
# The .npz file holds the data and the stimulation vector while the .yml file holds the metadata.
#
# It has been specifically conceived for BCI data.
#
# This script is for BI2013a Non Adaptative/Training

# %%
#import essential libraries

import numpy as np
import pandas as pd
import glob, os, sys, yaml
from yaml import CLoader as Loader, CDumper as Dumper
import moabb
from moabb.paradigms import P300

# %%
# Verify the epochs shape, labels, and metadata of BI2013a if wanted
# Epoch shape >>> trials X channels X time_samples

paradigm = P300()
dataset = moabb.datasets.BI2013a()
subjects = dataset.subject_list

epochs, labels, meta = paradigm.get_data(dataset=dataset, subjects = [subjects[0]], return_epochs = True)
# Out:
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\datasets\preprocessing.py:278: UserWarning: warnEpochs <Epochs | 480 events (all good), 0 – 1 s (baseline off), ~30.1 MiB, data loaded,
#  'Target': 80
#  'NonTarget': 400>
#   warn(f"warnEpochs {epochs}")
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# Adding metadata with 3 columns
# 3840 matching events found
# No baseline correction applied
# c:\Users\doumif\.conda\envs\py310\lib\site-packages\moabb\paradigms\base.py:350: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   X = mne.concatenate_epochs(X)

# %%
epochs.ch_names
# Out:
# ['Fp1',
#  'Fp2',
#  'F5',
#  'AFz',
#  'F6',
#  'T7',
#  'Cz',
#  'T8',
#  'P7',
#  'P3',
#  'Pz',
#  'P4',
#  'P8',
#  'O1',
#  'Oz',
#  'O2']

# %%
event_labels = dataset.event_id
event_labels
# Out:
# {'Target': 33285, 'NonTarget': 33286}

# %%
# Forward your file with all .csv of the dataset

file_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files #check if you have .csv files
# Out:
# ['C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT\\subject_24_session_01.csv']

# %%
#Calc windowlength
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
windowlength = np.diff(dataset.interval)[0]*samplingrate
windowlength
# Out:
# 256

# %%
#YML creator 
#The Meta data of the Data set
#These variables and parameters should address once for each data set.  

#######################################Acquisition#######################################
filter= 'Low-Pass 83Hz (Butterworth order 4 zero phase) for downsampling'
ground='FZ'
hardware= 'g.tec EEG'
reference= 'Left ear-lobe'
samplingrate = 256 # original data was downsampled to 256Hz, original = 512Hz (available in dataset description)
sensors = epochs.ch_names
sensortype ='Ag/AgCl Wet electrodes'
software= 'OpenVibe'

######################################Documentation######################################
description= 'https://hal.science/hal-02103098'
doi= 'https://doi.org/10.5281/zenodo.1494163'
investigators= "Vaineau, Barachant, Andreev, Rodrigues, Cattan, Congedo"
place= 'University of Grenoble Alpes, GipsaLab France'
repository= 'https://github.com/plcrodrigues/py.BI.EEG.2013-GIPSA'
##id
condition= 'Non Adaptative - Training' 
database= 'bi2013a'  
paradigm= 'P300'
timestamp= 2013

##########################################Stim###########################################
####Labels
event_labels = dict(NonTarget=1, Target=2)
nclasses= len(event_labels.keys())
offset= 0
windowlength = 256 

#########################################Subjects########################################  
subjects=len(dataset.subject_list)
runs=1
# session = //// for bi2013a, number of sessions for the first 7 subjects
# is 8, and for the rest is only 1 (you can see this in the loop line 85)

#function of YMLcreator
def YMLcreator():
  

  d = dict(acquisition=dict
          (filter= str(filter),
          ground=str(ground),
          hardware=str(hardware),
          reference=str(reference),
          samplingrate= samplingrate,
          sensors= sensors,
          sensortype=str(sensortype),
          software=str(software)
          )
          ,documentation=dict
          (description=str(description),
          doi=str(doi),
          investigators=str(investigators),
          place=str(place),
          repository=str(repository)
          )              
          ,
          formatversion=str('0.0.1')
          ,
          id=dict
          (condition=str(condition),
          database=str(database),
          paradigm=str(paradigm),
          subject=subject,
          session=session,
          run=run,
          timestamp=timestamp,
          )
          ,stim=dict
          (labels=event_labels,
          nclasses=nclasses,
          offset=offset,
          windowlength=windowlength,
          )
          
  )
  return d  

i=-1 #don't change i

for subject in range(1,subjects+1):
    sessions = 8 if subject <= 7 else 1
    for session in range(1,sessions+1):
        i=i+1
        filepath = all_files[i]
        for run in range(1,runs+1):
            d=YMLcreator()
            
            newpath=os.path.splitext(filepath)[0] + '.yml'
            with open(newpath, 'w') as file:
              documents = yaml.dump(d, file)


              file.write("""
##############################################################################
#                     GIPSA-lab standard for EEG time series (version 0.0.1) #
#                                Authors : Pedro Rodrigues and Marco Congedo #
#                                                        November 15th, 2019 #
##############################################################################

# This format has been conceived for easily sharing EEG data in Python and 
# Julia. Each file is understood as a separate recording. Data consist of two
# files. They have the same name and extensions `npz` and `yml` (this file).

# The `npz` file typically holds the EEG data matrix, a real matrix of 
# dimension num. of samples x num. of electrodes and a vector of integer with
# the tags for stimulations, with as many entries as number of samples. The 
# tags are 0 (zero) for no stimulation and then employs the natural numbers 
# (1, 2,...) for different stimulation classes.

# The `yml` file holds all meta-data info of the recording in `yml` format. 
# It holds two fields and four dictionaries:

# FIELDS:
#
# - paradigm: (string) the experimental paradigm, e.g., P300, MI, ... 
#             for Brain Computer Interfaces experiments
#
# - formatversion: (version) version of this metadata specification

# DICTIONARIES:
#
# - acquisition: (dictionary)
#
#   - filter: (string) filter setting of the EEG acquisition machine, 
#             specifying the type and specification. Ex: "Band-pass digital 
#             filter (0.01-70Hz)"
#   - ground: (string) location of the sensor used as ground. Ex: "Fpz"
#   - reference: (string) location of the sensor used as reference for the 
#                recording. Ex: "A1"
#   - hardware: (string) the commercial name and producer of the the EEG 
#               acquisition machine. Ex: "actiCHamp, Brain Products GmbH 
#               (Germany), DC amplifiers"
#   - software: (string) software used for acquiring and storing the data. 
#               Ex: OpenViBE, INRIA (France)
#   - samplingrate:(int) sampling rate. Ex: 128
#   - sensors: (array-like of strings) location of the sensors, excluding 
#              ground and reference.
#   - sensortype: (string) type, material and product name of electrodes. 
#                 Ex: Ag/AgCl, Braincap, Brain Products GmbH (Germany)
#
# - documentation: (dictionary)
#
#   - description: (string) link to a file or website describing the dataset
#   - doi: (string) digital object identifier of the dataset's documentation
#   - repository:  (string) link to the online repository where the data can 
#                  be downloaded
#
# - id: (dictionary)
#   
#   - database: (string) name of the database
#
# - stim: (dictionary)
#
#   - labels: (dictionary) dictionary with the labels and code of the 
#             stimulations
#       - nclasses: (int) number of classes for the stimulations
#       - offset: (int) offset, given in number of samples, with respect to 
#                 stimulation samples, defining the beginning of trials
#       - windowlength: (int) size of the window, given in number of sample, 
#                       defining the duration of trials
""")

# %%
##NPZ creator

#the Structure of the Data sets 
"""
The data should be in the form of  Samples*Channels, where channels may include a column for the time,
a column for the ground, a colum for the trigger, and a colum for the target. So, you need to drop the
columns of time and ground and add the two columns of trigger and target together(If you have not already done so).
"""

timestamp_col = 0  
stim_col= 17 # Stim target

#NPZ creator

def csv2npz(filepath):

    df= pd.read_csv(filepath, header=0) # header = 0 to remove header
    df= np.array(df)
    
    # from V to µV
    raw_data = df[:, 1:-1] * 1e6  

    DATA = np.float32(raw_data)
    print(DATA.shape)

    # STIM col
    STIM = np.int16(df[:, stim_col]) 

    unique_values, counts = np.unique(STIM, return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans {filepath} : Nombre de {value} = {count}")

    newpath=os.path.splitext(filepath)[0] + '.npz'
    np.savez(newpath,data=DATA , stim=STIM)

for f in all_files:
    csv2npz(f)
# Out:
# (69776, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_01.csv : Nombre de 0 = 69296
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_01.csv : Nombre de 2 = 80
# (69392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_02.csv : Nombre de 0 = 68912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_02.csv : Nombre de 2 = 80
# (66512, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_03.csv : Nombre de 0 = 66032
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_03.csv : Nombre de 2 = 80
# (66672, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_04.csv : Nombre de 0 = 66192
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_04.csv : Nombre de 2 = 80
# (64592, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_05.csv : Nombre de 0 = 64112
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_05.csv : Nombre de 2 = 80
# (65264, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_06.csv : Nombre de 0 = 64784
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_06.csv : Nombre de 2 = 80
# (64432, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_07.csv : Nombre de 0 = 63952
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_07.csv : Nombre de 2 = 80
# (66032, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_08.csv : Nombre de 0 = 65552
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_01_session_08.csv : Nombre de 2 = 80
# (119600, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_01.csv : Nombre de 0 = 119096
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_01.csv : Nombre de 1 = 420
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_01.csv : Nombre de 2 = 84
# (70544, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_02.csv : Nombre de 0 = 70064
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_02.csv : Nombre de 2 = 80
# (66240, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_03.csv : Nombre de 0 = 65760
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_03.csv : Nombre de 2 = 80
# (67872, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_04.csv : Nombre de 0 = 67392
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_04.csv : Nombre de 2 = 80
# (68272, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_05.csv : Nombre de 0 = 67792
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_05.csv : Nombre de 2 = 80
# (69824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_06.csv : Nombre de 0 = 69344
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_06.csv : Nombre de 2 = 80
# (68144, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_07.csv : Nombre de 0 = 67664
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_07.csv : Nombre de 2 = 80
# (69568, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_08.csv : Nombre de 0 = 69088
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_02_session_08.csv : Nombre de 2 = 80
# (80000, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_01.csv : Nombre de 0 = 79520
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_01.csv : Nombre de 2 = 80
# (69648, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_02.csv : Nombre de 0 = 69168
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_02.csv : Nombre de 2 = 80
# (71040, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_03.csv : Nombre de 0 = 70560
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_03.csv : Nombre de 2 = 80
# (71392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_04.csv : Nombre de 0 = 70912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_04.csv : Nombre de 2 = 80
# (68832, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_05.csv : Nombre de 0 = 68352
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_05.csv : Nombre de 2 = 80
# (71168, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_06.csv : Nombre de 0 = 70688
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_06.csv : Nombre de 2 = 80
# (68288, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_07.csv : Nombre de 0 = 67808
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_07.csv : Nombre de 2 = 80
# (67072, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_08.csv : Nombre de 0 = 66592
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_03_session_08.csv : Nombre de 2 = 80
# (74944, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_01.csv : Nombre de 0 = 74464
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_01.csv : Nombre de 2 = 80
# (67536, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_02.csv : Nombre de 0 = 67056
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_02.csv : Nombre de 2 = 80
# (69744, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_03.csv : Nombre de 0 = 69264
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_03.csv : Nombre de 2 = 80
# (67824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_04.csv : Nombre de 0 = 67344
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_04.csv : Nombre de 2 = 80
# (68736, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_05.csv : Nombre de 0 = 68256
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_05.csv : Nombre de 2 = 80
# (68384, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_06.csv : Nombre de 0 = 67904
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_06.csv : Nombre de 2 = 80
# (69088, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_07.csv : Nombre de 0 = 68608
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_07.csv : Nombre de 2 = 80
# (66080, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_08.csv : Nombre de 0 = 65600
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_04_session_08.csv : Nombre de 2 = 80
# (69312, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_01.csv : Nombre de 0 = 68832
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_01.csv : Nombre de 2 = 80
# (74592, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_02.csv : Nombre de 0 = 74112
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_02.csv : Nombre de 2 = 80
# (71120, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_03.csv : Nombre de 0 = 70640
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_03.csv : Nombre de 2 = 80
# (69584, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_04.csv : Nombre de 0 = 69104
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_04.csv : Nombre de 2 = 80
# (69872, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_05.csv : Nombre de 0 = 69392
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_05.csv : Nombre de 2 = 80
# (67824, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_06.csv : Nombre de 0 = 67344
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_06.csv : Nombre de 2 = 80
# (67392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_07.csv : Nombre de 0 = 66912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_07.csv : Nombre de 2 = 80
# (66256, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_08.csv : Nombre de 0 = 65776
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_05_session_08.csv : Nombre de 2 = 80
# (67056, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_01.csv : Nombre de 0 = 66576
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_01.csv : Nombre de 2 = 80
# (66192, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_02.csv : Nombre de 0 = 65712
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_02.csv : Nombre de 2 = 80
# (68688, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_03.csv : Nombre de 0 = 68208
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_03.csv : Nombre de 2 = 80
# (67712, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_04.csv : Nombre de 0 = 67232
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_04.csv : Nombre de 2 = 80
# (66768, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_05.csv : Nombre de 0 = 66288
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_05.csv : Nombre de 2 = 80
# (70640, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_06.csv : Nombre de 0 = 70160
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_06.csv : Nombre de 2 = 80
# (67344, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_07.csv : Nombre de 0 = 66864
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_07.csv : Nombre de 2 = 80
# (67744, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_08.csv : Nombre de 0 = 67264
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_06_session_08.csv : Nombre de 2 = 80
# (83248, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_01.csv : Nombre de 0 = 82768
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_01.csv : Nombre de 2 = 80
# (66336, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_02.csv : Nombre de 0 = 65856
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_02.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_02.csv : Nombre de 2 = 80
# (69424, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_03.csv : Nombre de 0 = 68944
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_03.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_03.csv : Nombre de 2 = 80
# (67760, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_04.csv : Nombre de 0 = 67280
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_04.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_04.csv : Nombre de 2 = 80
# (69120, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_05.csv : Nombre de 0 = 68640
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_05.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_05.csv : Nombre de 2 = 80
# (67392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_06.csv : Nombre de 0 = 66912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_06.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_06.csv : Nombre de 2 = 80
# (66528, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_07.csv : Nombre de 0 = 66048
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_07.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_07.csv : Nombre de 2 = 80
# (67888, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_08.csv : Nombre de 0 = 67408
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_08.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_07_session_08.csv : Nombre de 2 = 80
# (63312, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_08_session_01.csv : Nombre de 0 = 62832
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_08_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_08_session_01.csv : Nombre de 2 = 80
# (72688, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_09_session_01.csv : Nombre de 0 = 72208
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_09_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_09_session_01.csv : Nombre de 2 = 80
# (65152, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_10_session_01.csv : Nombre de 0 = 64672
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_10_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_10_session_01.csv : Nombre de 2 = 80
# (69008, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_11_session_01.csv : Nombre de 0 = 68528
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_11_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_11_session_01.csv : Nombre de 2 = 80
# (69648, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_12_session_01.csv : Nombre de 0 = 69168
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_12_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_12_session_01.csv : Nombre de 2 = 80
# (65072, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_13_session_01.csv : Nombre de 0 = 64592
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_13_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_13_session_01.csv : Nombre de 2 = 80
# (69696, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_14_session_01.csv : Nombre de 0 = 69216
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_14_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_14_session_01.csv : Nombre de 2 = 80
# (68752, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_15_session_01.csv : Nombre de 0 = 68272
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_15_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_15_session_01.csv : Nombre de 2 = 80
# (67808, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_16_session_01.csv : Nombre de 0 = 67328
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_16_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_16_session_01.csv : Nombre de 2 = 80
# (68704, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_17_session_01.csv : Nombre de 0 = 68224
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_17_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_17_session_01.csv : Nombre de 2 = 80
# (66688, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_18_session_01.csv : Nombre de 0 = 66208
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_18_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_18_session_01.csv : Nombre de 2 = 80
# (70048, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_19_session_01.csv : Nombre de 0 = 69568
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_19_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_19_session_01.csv : Nombre de 2 = 80
# (65504, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_20_session_01.csv : Nombre de 0 = 65024
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_20_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_20_session_01.csv : Nombre de 2 = 80
# (68592, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_21_session_01.csv : Nombre de 0 = 68112
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_21_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_21_session_01.csv : Nombre de 2 = 80
# (69552, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_22_session_01.csv : Nombre de 0 = 69072
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_22_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_22_session_01.csv : Nombre de 2 = 80
# (73040, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_23_session_01.csv : Nombre de 0 = 72560
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_23_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_23_session_01.csv : Nombre de 2 = 80
# (67392, 16)
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_24_session_01.csv : Nombre de 0 = 66912
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_24_session_01.csv : Nombre de 1 = 400
# Dans C:\Users\doumif\work\OfficeWork\BCI Databases\CSV\P300\bi2013a-NAT\subject_24_session_01.csv : Nombre de 2 = 80
