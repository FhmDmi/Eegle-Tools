# %% [markdown]
# RAW (MOABB) to CSV
#
# This code convert the data sets from RAW format to CSV format using MOABB.
#
# It has been specifically conceived for BCI data.
#
# This script is for bi2013a-AO

# %%
import numpy as np
import pandas as pd
import os
import shutil

# %%
def reorganize(source_folder, destination_folder):
    """
    Reorganizes the 1.csv files from each subject/session into a new folder.
    Ensures subject and session numbers are formatted with leading zeros.

    Args:
        source_folder: Path to the folder containing all subjects
        destination_folder: Path to the folder where renamed files will be copied
    """
    # Create destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Loop through all subject folders
    for subject_folder in os.listdir(source_folder):
        subject_path = os.path.join(source_folder, subject_folder)

        # Check if it's a directory
        if not os.path.isdir(subject_path):
            continue

        # Extract subject number
        if subject_folder.startswith("subject"):
            if "_session" in subject_folder:
                # Format: subject01_session01
                subject_num = int(subject_folder.split("_session")[0].replace("subject", ""))
                session_num = int(subject_folder.split("_session")[1])
            else:
                # Format: subject08, subject09, etc.
                subject_num = int(subject_folder.replace("subject", ""))
                session_num = 1  # Only one session for subjects 8-24

            # Look for the Session folder
            for item in os.listdir(subject_path):
                if item.startswith("Session"):
                    session_path = os.path.join(subject_path, item)

                    # Look for the 2.csv file
                    csv_file = os.path.join(session_path, "2.csv")
                    if os.path.exists(csv_file):
                        # Create new filename
                        new_name = f"subject_{subject_num:02d}_session_{session_num:02d}.csv"
                        destination_path = os.path.join(destination_folder, new_name)

                        # Copy the file with the new name
                        shutil.copy2(csv_file, destination_path)
                        print(f"Copied: {csv_file} -> {destination_path}")

    print(f"Reorganization completed. Files are in: {destination_folder}")

# %%
source = "C:\\Users\\doumif\\Downloads\\CSV zenodo bi2013a\\"
destination = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\"

# %%
reorganize(source, destination)
# Out:
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_01_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_02_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_03_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_04_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_05_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_06_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session01\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session02\Session2\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session03\Session3\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session04\Session4\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session05\Session5\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session06\Session6\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session07\Session7\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session08\Session8\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_07_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject08\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_08_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject09\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_09_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject10\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_10_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject11\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_11_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject12\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_12_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject13\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_13_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject14\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_14_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject15\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_15_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject16\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_16_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject17\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_17_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject18\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_18_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject19\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_19_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject20\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_20_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject21\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_21_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject22\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_22_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject23\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_23_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject24\Session1\2.csv -> C:\Users\doumif\Downloads\CSV bi2013a-AO\subject_24_session_01.csv
# Reorganization completed. Files are in: C:\Users\doumif\Downloads\CSV bi2013a-AO\

# %%
# Forward your file with all .csv of the dataset
# Cattan files have been downloaded from the zenodo repository, and then reorganized as you have seen above. We need to "clean" it before converting to npz
file_dir = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\"
output_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-AO"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files
# Out:
# ['C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_24_session_01.csv']

# %%
file = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-AO\\subject_01_session_02.csv"

# %%
df = pd.read_csv(file, header=0)
data = np.array(df)

# %%
print(f"Unique values in stim column: {np.count_nonzero(data[:, 17])}\n")
# Out:
# Unique values in stim column: 168

# %%
unique_values, counts = np.unique(data[:, 17], return_counts=True)
for value, count in zip(unique_values, counts):
    print(f"Dans data : Nombre de {value} = {count}")
# Out:
# Dans data : Nombre de 0.0 = 104472
# Dans data : Nombre de 33285.0 = 28
# Dans data : Nombre de 33286.0 = 140

# %%
def process_eeg_file(file_path, output_dir):
    """
    Process a single EEG file and save it with a new format.

    Parameters:
    -----------
    file_path : str
        Path to the input CSV file
    output_dir : str
        Directory where processed file will be saved

    Returns:
    --------
    str
        Path to the processed file

    The function:
    - Reads the CSV file
    - Processes the data (merges target/non-target columns, removes unnecessary columns)
    - Saves processed file with format 'subject_XX_session_01.csv'
    """
    # Extract subject number from filename (assuming format like 'subject_01_PC.csv')
    filename = os.path.basename(file_path)

    # Read and process the data
    df = pd.read_csv(file_path, header=None)
    data = np.array(df)

    # 1. Merge target and non-target columns
    # Convert 33285 to 2 and 33286 to 1 in target column (column 18)
    data[:, 17] = np.where(data[:, 17] == 33285, 2, 
                  np.where(data[:, 17] == 33286, 1, 
                           data[:, 17]))

    # Convert back to DataFrame
    df_processed = pd.DataFrame(data)

    # Save processed file
    output_path = os.path.join(output_dir, filename)
    df_processed.to_csv(output_path, index=False, header=False)

    print(f"Processed and saved: {filename}")
    print(f"Shape: {data.shape}")
    unique_values, counts = np.unique(data[:, 17], return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans data : Nombre de {value} = {count}")

    return output_path

# %%
# 16 corresponds to the haeder
for i, file in enumerate(all_files, 1):
    print(f"File number {i} out of {len(all_files)}")
    csv = process_eeg_file(file, output_dir)
# Out:
# File number 1 out of 73
# Processed and saved: subject_01_session_01.csv
# Shape: (125185, 18)
# Dans data : Nombre de 0.0 = 124992
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 2 out of 73
# Processed and saved: subject_01_session_02.csv
# Shape: (104641, 18)
# Dans data : Nombre de 0.0 = 104472
# Dans data : Nombre de 1.0 = 140
# Dans data : Nombre de 2.0 = 28
# Dans data : Nombre de 16.0 = 1
# File number 3 out of 73
# Processed and saved: subject_01_session_03.csv
# Shape: (101185, 18)
# Dans data : Nombre de 0.0 = 101028
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 4 out of 73
# Processed and saved: subject_01_session_04.csv
# Shape: (97505, 18)
# Dans data : Nombre de 0.0 = 97360
# Dans data : Nombre de 1.0 = 120
# Dans data : Nombre de 2.0 = 24
# Dans data : Nombre de 16.0 = 1
# File number 5 out of 73
# Processed and saved: subject_01_session_05.csv
# Shape: (114049, 18)
# Dans data : Nombre de 0.0 = 113844
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 6 out of 73
# Processed and saved: subject_01_session_06.csv
# Shape: (102529, 18)
# Dans data : Nombre de 0.0 = 102384
# Dans data : Nombre de 1.0 = 120
# Dans data : Nombre de 2.0 = 24
# Dans data : Nombre de 16.0 = 1
# File number 7 out of 73
# Processed and saved: subject_01_session_07.csv
# Shape: (104577, 18)
# Dans data : Nombre de 0.0 = 104384
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 8 out of 73
# Processed and saved: subject_01_session_08.csv
# Shape: (94561, 18)
# Dans data : Nombre de 0.0 = 94404
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 9 out of 73
# Processed and saved: subject_02_session_01.csv
# Shape: (138849, 18)
# Dans data : Nombre de 0.0 = 138572
# Dans data : Nombre de 1.0 = 230
# Dans data : Nombre de 2.0 = 46
# Dans data : Nombre de 16.0 = 1
# File number 10 out of 73
# Processed and saved: subject_02_session_02.csv
# Shape: (121345, 18)
# Dans data : Nombre de 0.0 = 121104
# Dans data : Nombre de 1.0 = 200
# Dans data : Nombre de 2.0 = 40
# Dans data : Nombre de 16.0 = 1
# File number 11 out of 73
# Processed and saved: subject_02_session_03.csv
# Shape: (108833, 18)
# Dans data : Nombre de 0.0 = 108652
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 12 out of 73
# Processed and saved: subject_02_session_04.csv
# Shape: (113441, 18)
# Dans data : Nombre de 0.0 = 113260
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 13 out of 73
# Processed and saved: subject_02_session_05.csv
# Shape: (113569, 18)
# Dans data : Nombre de 0.0 = 113352
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 14 out of 73
# Processed and saved: subject_02_session_06.csv
# Shape: (133025, 18)
# Dans data : Nombre de 0.0 = 132736
# Dans data : Nombre de 1.0 = 240
# Dans data : Nombre de 2.0 = 48
# Dans data : Nombre de 16.0 = 1
# File number 15 out of 73
# Processed and saved: subject_02_session_07.csv
# Shape: (102113, 18)
# Dans data : Nombre de 0.0 = 101932
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 16 out of 73
# Processed and saved: subject_02_session_08.csv
# Shape: (105249, 18)
# Dans data : Nombre de 0.0 = 105068
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 17 out of 73
# Processed and saved: subject_03_session_01.csv
# Shape: (136353, 18)
# Dans data : Nombre de 0.0 = 136088
# Dans data : Nombre de 1.0 = 220
# Dans data : Nombre de 2.0 = 44
# Dans data : Nombre de 16.0 = 1
# File number 18 out of 73
# Processed and saved: subject_03_session_02.csv
# Shape: (118977, 18)
# Dans data : Nombre de 0.0 = 118748
# Dans data : Nombre de 1.0 = 190
# Dans data : Nombre de 2.0 = 38
# Dans data : Nombre de 16.0 = 1
# File number 19 out of 73
# Processed and saved: subject_03_session_03.csv
# Shape: (117153, 18)
# Dans data : Nombre de 0.0 = 116948
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 20 out of 73
# Processed and saved: subject_03_session_04.csv
# Shape: (110529, 18)
# Dans data : Nombre de 0.0 = 110336
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 21 out of 73
# Processed and saved: subject_03_session_05.csv
# Shape: (101537, 18)
# Dans data : Nombre de 0.0 = 101356
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 22 out of 73
# Processed and saved: subject_03_session_06.csv
# Shape: (97217, 18)
# Dans data : Nombre de 0.0 = 97060
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 23 out of 73
# Processed and saved: subject_03_session_07.csv
# Shape: (101089, 18)
# Dans data : Nombre de 0.0 = 100908
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 24 out of 73
# Processed and saved: subject_03_session_08.csv
# Shape: (123137, 18)
# Dans data : Nombre de 0.0 = 122872
# Dans data : Nombre de 1.0 = 220
# Dans data : Nombre de 2.0 = 44
# Dans data : Nombre de 16.0 = 1
# File number 25 out of 73
# Processed and saved: subject_04_session_01.csv
# Shape: (110145, 18)
# Dans data : Nombre de 0.0 = 109964
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 26 out of 73
# Processed and saved: subject_04_session_02.csv
# Shape: (133729, 18)
# Dans data : Nombre de 0.0 = 133452
# Dans data : Nombre de 1.0 = 230
# Dans data : Nombre de 2.0 = 46
# Dans data : Nombre de 16.0 = 1
# File number 27 out of 73
# Processed and saved: subject_04_session_03.csv
# Shape: (118913, 18)
# Dans data : Nombre de 0.0 = 118696
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 28 out of 73
# Processed and saved: subject_04_session_04.csv
# Shape: (125089, 18)
# Dans data : Nombre de 0.0 = 124836
# Dans data : Nombre de 1.0 = 210
# Dans data : Nombre de 2.0 = 42
# Dans data : Nombre de 16.0 = 1
# File number 29 out of 73
# Processed and saved: subject_04_session_05.csv
# Shape: (120289, 18)
# Dans data : Nombre de 0.0 = 120060
# Dans data : Nombre de 1.0 = 190
# Dans data : Nombre de 2.0 = 38
# Dans data : Nombre de 16.0 = 1
# File number 30 out of 73
# Processed and saved: subject_04_session_06.csv
# Shape: (101409, 18)
# Dans data : Nombre de 0.0 = 101228
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 31 out of 73
# Processed and saved: subject_04_session_07.csv
# Shape: (106657, 18)
# Dans data : Nombre de 0.0 = 106452
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 32 out of 73
# Processed and saved: subject_04_session_08.csv
# Shape: (129409, 18)
# Dans data : Nombre de 0.0 = 129180
# Dans data : Nombre de 1.0 = 190
# Dans data : Nombre de 2.0 = 38
# Dans data : Nombre de 16.0 = 1
# File number 33 out of 73
# Processed and saved: subject_05_session_01.csv
# Shape: (122401, 18)
# Dans data : Nombre de 0.0 = 122196
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 34 out of 73
# Processed and saved: subject_05_session_02.csv
# Shape: (110497, 18)
# Dans data : Nombre de 0.0 = 110304
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 35 out of 73
# Processed and saved: subject_05_session_03.csv
# Shape: (138401, 18)
# Dans data : Nombre de 0.0 = 138112
# Dans data : Nombre de 1.0 = 240
# Dans data : Nombre de 2.0 = 48
# Dans data : Nombre de 16.0 = 1
# File number 36 out of 73
# Processed and saved: subject_05_session_04.csv
# Shape: (111233, 18)
# Dans data : Nombre de 0.0 = 111016
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 37 out of 73
# Processed and saved: subject_05_session_05.csv
# Shape: (100353, 18)
# Dans data : Nombre de 0.0 = 100184
# Dans data : Nombre de 1.0 = 140
# Dans data : Nombre de 2.0 = 28
# Dans data : Nombre de 16.0 = 1
# File number 38 out of 73
# Processed and saved: subject_05_session_06.csv
# Shape: (111425, 18)
# Dans data : Nombre de 0.0 = 111220
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 39 out of 73
# Processed and saved: subject_05_session_07.csv
# Shape: (102049, 18)
# Dans data : Nombre de 0.0 = 101880
# Dans data : Nombre de 1.0 = 140
# Dans data : Nombre de 2.0 = 28
# Dans data : Nombre de 16.0 = 1
# File number 40 out of 73
# Processed and saved: subject_05_session_08.csv
# Shape: (110881, 18)
# Dans data : Nombre de 0.0 = 110688
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 41 out of 73
# Processed and saved: subject_06_session_01.csv
# Shape: (133505, 18)
# Dans data : Nombre de 0.0 = 133216
# Dans data : Nombre de 1.0 = 240
# Dans data : Nombre de 2.0 = 48
# Dans data : Nombre de 16.0 = 1
# File number 42 out of 73
# Processed and saved: subject_06_session_02.csv
# Shape: (124577, 18)
# Dans data : Nombre de 0.0 = 124324
# Dans data : Nombre de 1.0 = 210
# Dans data : Nombre de 2.0 = 42
# Dans data : Nombre de 16.0 = 1
# File number 43 out of 73
# Processed and saved: subject_06_session_03.csv
# Shape: (108161, 18)
# Dans data : Nombre de 0.0 = 107980
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 44 out of 73
# Processed and saved: subject_06_session_04.csv
# Shape: (128673, 18)
# Dans data : Nombre de 0.0 = 128396
# Dans data : Nombre de 1.0 = 230
# Dans data : Nombre de 2.0 = 46
# Dans data : Nombre de 16.0 = 1
# File number 45 out of 73
# Processed and saved: subject_06_session_05.csv
# Shape: (117825, 18)
# Dans data : Nombre de 0.0 = 117608
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 46 out of 73
# Processed and saved: subject_06_session_06.csv
# Shape: (103457, 18)
# Dans data : Nombre de 0.0 = 103264
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 47 out of 73
# Processed and saved: subject_06_session_07.csv
# Shape: (112481, 18)
# Dans data : Nombre de 0.0 = 112264
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 48 out of 73
# Processed and saved: subject_06_session_08.csv
# Shape: (138721, 18)
# Dans data : Nombre de 0.0 = 138396
# Dans data : Nombre de 1.0 = 270
# Dans data : Nombre de 2.0 = 54
# Dans data : Nombre de 16.0 = 1
# File number 49 out of 73
# Processed and saved: subject_07_session_01.csv
# Shape: (172993, 18)
# Dans data : Nombre de 0.0 = 172788
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 50 out of 73
# Processed and saved: subject_07_session_02.csv
# Shape: (103649, 18)
# Dans data : Nombre de 0.0 = 103480
# Dans data : Nombre de 1.0 = 140
# Dans data : Nombre de 2.0 = 28
# Dans data : Nombre de 16.0 = 1
# File number 51 out of 73
# Processed and saved: subject_07_session_03.csv
# Shape: (99009, 18)
# Dans data : Nombre de 0.0 = 98840
# Dans data : Nombre de 1.0 = 140
# Dans data : Nombre de 2.0 = 28
# Dans data : Nombre de 16.0 = 1
# File number 52 out of 73
# Processed and saved: subject_07_session_04.csv
# Shape: (101409, 18)
# Dans data : Nombre de 0.0 = 101228
# Dans data : Nombre de 1.0 = 150
# Dans data : Nombre de 2.0 = 30
# Dans data : Nombre de 16.0 = 1
# File number 53 out of 73
# Processed and saved: subject_07_session_05.csv
# Shape: (91937, 18)
# Dans data : Nombre de 0.0 = 91780
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 54 out of 73
# Processed and saved: subject_07_session_06.csv
# Shape: (94369, 18)
# Dans data : Nombre de 0.0 = 94212
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 55 out of 73
# Processed and saved: subject_07_session_07.csv
# Shape: (93729, 18)
# Dans data : Nombre de 0.0 = 93572
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 56 out of 73
# Processed and saved: subject_07_session_08.csv
# Shape: (93537, 18)
# Dans data : Nombre de 0.0 = 93380
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 57 out of 73
# Processed and saved: subject_08_session_01.csv
# Shape: (121377, 18)
# Dans data : Nombre de 0.0 = 121136
# Dans data : Nombre de 1.0 = 200
# Dans data : Nombre de 2.0 = 40
# Dans data : Nombre de 16.0 = 1
# File number 58 out of 73
# Processed and saved: subject_09_session_01.csv
# Shape: (116353, 18)
# Dans data : Nombre de 0.0 = 116136
# Dans data : Nombre de 1.0 = 180
# Dans data : Nombre de 2.0 = 36
# Dans data : Nombre de 16.0 = 1
# File number 59 out of 73
# Processed and saved: subject_10_session_01.csv
# Shape: (141537, 18)
# Dans data : Nombre de 0.0 = 141200
# Dans data : Nombre de 1.0 = 280
# Dans data : Nombre de 2.0 = 56
# Dans data : Nombre de 16.0 = 1
# File number 60 out of 73
# Processed and saved: subject_11_session_01.csv
# Shape: (147233, 18)
# Dans data : Nombre de 0.0 = 146908
# Dans data : Nombre de 1.0 = 270
# Dans data : Nombre de 2.0 = 54
# Dans data : Nombre de 16.0 = 1
# File number 61 out of 73
# Processed and saved: subject_12_session_01.csv
# Shape: (145057, 18)
# Dans data : Nombre de 0.0 = 144732
# Dans data : Nombre de 1.0 = 270
# Dans data : Nombre de 2.0 = 54
# Dans data : Nombre de 16.0 = 1
# File number 62 out of 73
# Processed and saved: subject_13_session_01.csv
# Shape: (122465, 18)
# Dans data : Nombre de 0.0 = 122212
# Dans data : Nombre de 1.0 = 210
# Dans data : Nombre de 2.0 = 42
# Dans data : Nombre de 16.0 = 1
# File number 63 out of 73
# Processed and saved: subject_14_session_01.csv
# Shape: (107457, 18)
# Dans data : Nombre de 0.0 = 107264
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 64 out of 73
# Processed and saved: subject_15_session_01.csv
# Shape: (97057, 18)
# Dans data : Nombre de 0.0 = 96900
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 65 out of 73
# Processed and saved: subject_16_session_01.csv
# Shape: (109057, 18)
# Dans data : Nombre de 0.0 = 108852
# Dans data : Nombre de 1.0 = 170
# Dans data : Nombre de 2.0 = 34
# Dans data : Nombre de 16.0 = 1
# File number 66 out of 73
# Processed and saved: subject_17_session_01.csv
# Shape: (126753, 18)
# Dans data : Nombre de 0.0 = 126476
# Dans data : Nombre de 1.0 = 230
# Dans data : Nombre de 2.0 = 46
# Dans data : Nombre de 16.0 = 1
# File number 67 out of 73
# Processed and saved: subject_18_session_01.csv
# Shape: (115905, 18)
# Dans data : Nombre de 0.0 = 115748
# Dans data : Nombre de 1.0 = 130
# Dans data : Nombre de 2.0 = 26
# Dans data : Nombre de 16.0 = 1
# File number 68 out of 73
# Processed and saved: subject_19_session_01.csv
# Shape: (115873, 18)
# Dans data : Nombre de 0.0 = 115644
# Dans data : Nombre de 1.0 = 190
# Dans data : Nombre de 2.0 = 38
# Dans data : Nombre de 16.0 = 1
# File number 69 out of 73
# Processed and saved: subject_20_session_01.csv
# Shape: (119009, 18)
# Dans data : Nombre de 0.0 = 118768
# Dans data : Nombre de 1.0 = 200
# Dans data : Nombre de 2.0 = 40
# Dans data : Nombre de 16.0 = 1
# File number 70 out of 73
# Processed and saved: subject_21_session_01.csv
# Shape: (105825, 18)
# Dans data : Nombre de 0.0 = 105632
# Dans data : Nombre de 1.0 = 160
# Dans data : Nombre de 2.0 = 32
# Dans data : Nombre de 16.0 = 1
# File number 71 out of 73
# Processed and saved: subject_22_session_01.csv
# Shape: (125025, 18)
# Dans data : Nombre de 0.0 = 124784
# Dans data : Nombre de 1.0 = 200
# Dans data : Nombre de 2.0 = 40
# Dans data : Nombre de 16.0 = 1
# File number 72 out of 73
# Processed and saved: subject_23_session_01.csv
# Shape: (133665, 18)
# Dans data : Nombre de 0.0 = 133364
# Dans data : Nombre de 1.0 = 250
# Dans data : Nombre de 2.0 = 50
# Dans data : Nombre de 16.0 = 1
# File number 73 out of 73
# Processed and saved: subject_24_session_01.csv
# Shape: (184193, 18)
# Dans data : Nombre de 0.0 = 183916
# Dans data : Nombre de 1.0 = 230
# Dans data : Nombre de 2.0 = 46
# Dans data : Nombre de 16.0 = 1
