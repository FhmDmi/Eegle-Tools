# %% [markdown]
# RAW (MOABB) to CSV
#
# This code convert the data sets from RAW format to CSV format using MOABB.
#
# It has been specifically conceived for BCI data.
#
# This script is for bi2013a-NAT

# %%
import numpy as np
import pandas as pd
import os
import shutil

# %%
def reorganize(source_folder, destination_folder):
    """
    Reorganizes the 1.csv files from each subject/session into a new folder.
    Ensures subject and session numbers are formatted with leading zeros.

    Args:
        source_folder: Path to the folder containing all subjects
        destination_folder: Path to the folder where renamed files will be copied
    """
    # Create destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Loop through all subject folders
    for subject_folder in os.listdir(source_folder):
        subject_path = os.path.join(source_folder, subject_folder)

        # Check if it's a directory
        if not os.path.isdir(subject_path):
            continue

        # Extract subject number
        if subject_folder.startswith("subject"):
            if "_session" in subject_folder:
                # Format: subject01_session01
                subject_num = int(subject_folder.split("_session")[0].replace("subject", ""))
                session_num = int(subject_folder.split("_session")[1])
            else:
                # Format: subject08, subject09, etc.
                subject_num = int(subject_folder.replace("subject", ""))
                session_num = 1  # Only one session for subjects 8-24

            # Look for the Session folder
            for item in os.listdir(subject_path):
                if item.startswith("Session"):
                    session_path = os.path.join(subject_path, item)

                    # Look for the 3.csv file
                    csv_file = os.path.join(session_path, "3.csv")
                    if os.path.exists(csv_file):
                        # Create new filename
                        new_name = f"subject_{subject_num:02d}_session_{session_num:02d}.csv"
                        destination_path = os.path.join(destination_folder, new_name)

                        # Copy the file with the new name
                        shutil.copy2(csv_file, destination_path)
                        print(f"Copied: {csv_file} -> {destination_path}")

    print(f"Reorganization completed. Files are in: {destination_folder}")

# %%
source = "C:\\Users\\doumif\\Downloads\\CSV zenodo bi2013a\\"
destination = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\"

# %%
reorganize(source, destination)
# Out:
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject01_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_01_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject02_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_02_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject03_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_03_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject04_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_04_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject05_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_05_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject06_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_06_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session01\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session02\Session2\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_02.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session03\Session3\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_03.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session04\Session4\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_04.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session05\Session5\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_05.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session06\Session6\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_06.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session07\Session7\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_07.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject07_session08\Session8\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_07_session_08.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject08\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_08_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject09\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_09_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject10\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_10_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject11\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_11_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject12\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_12_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject13\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_13_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject14\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_14_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject15\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_15_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject16\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_16_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject17\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_17_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject18\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_18_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject19\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_19_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject20\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_20_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject21\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_21_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject22\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_22_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject23\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_23_session_01.csv
# Copied: C:\Users\doumif\Downloads\CSV zenodo bi2013a\subject24\Session1\3.csv -> C:\Users\doumif\Downloads\CSV bi2013a-NAT\subject_24_session_01.csv
# Reorganization completed. Files are in: C:\Users\doumif\Downloads\CSV bi2013a-NAT\

# %%
# Forward your file with all .csv of the dataset
# Cattan files have been downloaded from the zenodo repository, and then reorganized as you have seen above. We need to "clean" it before converting to npz
file_dir = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\"
output_dir = "C:\\Users\\doumif\\work\\OfficeWork\\BCI Databases\\CSV\\P300\\bi2013a-NAT"
all_files = [os.path.join(file_dir, file) for file in os.listdir(file_dir)]
all_files
# Out:
# ['C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_01_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_02_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_03_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_04_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_05_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_06_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_02.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_03.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_04.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_05.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_06.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_07.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_07_session_08.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_08_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_09_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_10_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_11_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_12_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_13_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_14_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_15_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_16_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_17_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_18_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_19_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_20_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_21_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_22_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_23_session_01.csv',
#  'C:\\Users\\doumif\\Downloads\\CSV bi2013a-NAT\\subject_24_session_01.csv']

# %%
file = "C:\\Users\\doumif\\Downloads\\CSV bi2013a-AT\\subject_01_session_02.csv"

# %%
df = pd.read_csv(file, header=0)
data = np.array(df)

# %%
print(f"Unique values in stim column: {np.count_nonzero(data[:, 17])}\n")
# Out:
# Unique values in stim column: 480

# %%
unique_values, counts = np.unique(data[:, 17], return_counts=True)
for value, count in zip(unique_values, counts):
    print(f"Dans data : Nombre de {value} = {count}")
# Out:
# Dans data : Nombre de 0.0 = 132416
# Dans data : Nombre de 33285.0 = 80
# Dans data : Nombre de 33286.0 = 400

# %%
def process_eeg_file(file_path, output_dir):
    """
    Process a single EEG file and save it with a new format.

    Parameters:
    -----------
    file_path : str
        Path to the input CSV file
    output_dir : str
        Directory where processed file will be saved

    Returns:
    --------
    str
        Path to the processed file

    The function:
    - Reads the CSV file
    - Processes the data (merges target/non-target columns, removes unnecessary columns)
    - Saves processed file with format 'subject_XX_session_01.csv'
    """
    # Extract subject number from filename (assuming format like 'subject_01_PC.csv')
    filename = os.path.basename(file_path)

    # Read and process the data
    df = pd.read_csv(file_path, header=None)
    data = np.array(df)

    # 1. Merge target and non-target columns
    # Convert 33285 to 2 and 33286 to 1 in target column (column 18)
    data[:, 17] = np.where(data[:, 17] == 33285, 2, 
                  np.where(data[:, 17] == 33286, 1, 
                           data[:, 17]))

    # Convert back to DataFrame
    df_processed = pd.DataFrame(data)

    # Save processed file
    output_path = os.path.join(output_dir, filename)
    df_processed.to_csv(output_path, index=False, header=False)

    print(f"Processed and saved: {filename}")
    print(f"Shape: {data.shape}")
    unique_values, counts = np.unique(data[:, 17], return_counts=True)
    for value, count in zip(unique_values, counts):
        print(f"Dans data : Nombre de {value} = {count}")

    return output_path

# %%
# 16 corresponds to the haeder
for i, file in enumerate(all_files, 1):
    print(f"File number {i} out of {len(all_files)}")
    csv = process_eeg_file(file, output_dir)
# Out:
# File number 1 out of 73
# Processed and saved: subject_01_session_01.csv
# Shape: (139553, 18)
# Dans data : Nombre de 0.0 = 139072
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 2 out of 73
# Processed and saved: subject_01_session_02.csv
# Shape: (138785, 18)
# Dans data : Nombre de 0.0 = 138304
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 3 out of 73
# Processed and saved: subject_01_session_03.csv
# Shape: (133025, 18)
# Dans data : Nombre de 0.0 = 132544
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 4 out of 73
# Processed and saved: subject_01_session_04.csv
# Shape: (133345, 18)
# Dans data : Nombre de 0.0 = 132864
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 5 out of 73
# Processed and saved: subject_01_session_05.csv
# Shape: (129185, 18)
# Dans data : Nombre de 0.0 = 128704
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 6 out of 73
# Processed and saved: subject_01_session_06.csv
# Shape: (130529, 18)
# Dans data : Nombre de 0.0 = 130048
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 7 out of 73
# Processed and saved: subject_01_session_07.csv
# Shape: (128865, 18)
# Dans data : Nombre de 0.0 = 128384
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 8 out of 73
# Processed and saved: subject_01_session_08.csv
# Shape: (132065, 18)
# Dans data : Nombre de 0.0 = 131584
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 9 out of 73
# Processed and saved: subject_02_session_01.csv
# Shape: (239201, 18)
# Dans data : Nombre de 0.0 = 238696
# Dans data : Nombre de 1.0 = 420
# Dans data : Nombre de 2.0 = 84
# Dans data : Nombre de 16.0 = 1
# File number 10 out of 73
# Processed and saved: subject_02_session_02.csv
# Shape: (141089, 18)
# Dans data : Nombre de 0.0 = 140608
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 11 out of 73
# Processed and saved: subject_02_session_03.csv
# Shape: (132481, 18)
# Dans data : Nombre de 0.0 = 132000
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 12 out of 73
# Processed and saved: subject_02_session_04.csv
# Shape: (135745, 18)
# Dans data : Nombre de 0.0 = 135264
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 13 out of 73
# Processed and saved: subject_02_session_05.csv
# Shape: (136545, 18)
# Dans data : Nombre de 0.0 = 136064
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 14 out of 73
# Processed and saved: subject_02_session_06.csv
# Shape: (139649, 18)
# Dans data : Nombre de 0.0 = 139168
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 15 out of 73
# Processed and saved: subject_02_session_07.csv
# Shape: (136289, 18)
# Dans data : Nombre de 0.0 = 135808
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 16 out of 73
# Processed and saved: subject_02_session_08.csv
# Shape: (139137, 18)
# Dans data : Nombre de 0.0 = 138656
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 17 out of 73
# Processed and saved: subject_03_session_01.csv
# Shape: (160001, 18)
# Dans data : Nombre de 0.0 = 159520
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 18 out of 73
# Processed and saved: subject_03_session_02.csv
# Shape: (139297, 18)
# Dans data : Nombre de 0.0 = 138816
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 19 out of 73
# Processed and saved: subject_03_session_03.csv
# Shape: (142081, 18)
# Dans data : Nombre de 0.0 = 141600
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 20 out of 73
# Processed and saved: subject_03_session_04.csv
# Shape: (142785, 18)
# Dans data : Nombre de 0.0 = 142304
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 21 out of 73
# Processed and saved: subject_03_session_05.csv
# Shape: (137665, 18)
# Dans data : Nombre de 0.0 = 137184
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 22 out of 73
# Processed and saved: subject_03_session_06.csv
# Shape: (142337, 18)
# Dans data : Nombre de 0.0 = 141856
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 23 out of 73
# Processed and saved: subject_03_session_07.csv
# Shape: (136577, 18)
# Dans data : Nombre de 0.0 = 136096
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 24 out of 73
# Processed and saved: subject_03_session_08.csv
# Shape: (134145, 18)
# Dans data : Nombre de 0.0 = 133664
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 25 out of 73
# Processed and saved: subject_04_session_01.csv
# Shape: (149889, 18)
# Dans data : Nombre de 0.0 = 149408
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 26 out of 73
# Processed and saved: subject_04_session_02.csv
# Shape: (135073, 18)
# Dans data : Nombre de 0.0 = 134592
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 27 out of 73
# Processed and saved: subject_04_session_03.csv
# Shape: (139489, 18)
# Dans data : Nombre de 0.0 = 139008
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 28 out of 73
# Processed and saved: subject_04_session_04.csv
# Shape: (135649, 18)
# Dans data : Nombre de 0.0 = 135168
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 29 out of 73
# Processed and saved: subject_04_session_05.csv
# Shape: (137473, 18)
# Dans data : Nombre de 0.0 = 136992
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 30 out of 73
# Processed and saved: subject_04_session_06.csv
# Shape: (136769, 18)
# Dans data : Nombre de 0.0 = 136288
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 31 out of 73
# Processed and saved: subject_04_session_07.csv
# Shape: (138177, 18)
# Dans data : Nombre de 0.0 = 137696
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 32 out of 73
# Processed and saved: subject_04_session_08.csv
# Shape: (132161, 18)
# Dans data : Nombre de 0.0 = 131680
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 33 out of 73
# Processed and saved: subject_05_session_01.csv
# Shape: (138625, 18)
# Dans data : Nombre de 0.0 = 138144
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 34 out of 73
# Processed and saved: subject_05_session_02.csv
# Shape: (149185, 18)
# Dans data : Nombre de 0.0 = 148704
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 35 out of 73
# Processed and saved: subject_05_session_03.csv
# Shape: (142241, 18)
# Dans data : Nombre de 0.0 = 141760
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 36 out of 73
# Processed and saved: subject_05_session_04.csv
# Shape: (139169, 18)
# Dans data : Nombre de 0.0 = 138688
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 37 out of 73
# Processed and saved: subject_05_session_05.csv
# Shape: (139745, 18)
# Dans data : Nombre de 0.0 = 139264
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 38 out of 73
# Processed and saved: subject_05_session_06.csv
# Shape: (135649, 18)
# Dans data : Nombre de 0.0 = 135168
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 39 out of 73
# Processed and saved: subject_05_session_07.csv
# Shape: (134785, 18)
# Dans data : Nombre de 0.0 = 134304
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 40 out of 73
# Processed and saved: subject_05_session_08.csv
# Shape: (132513, 18)
# Dans data : Nombre de 0.0 = 132032
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 41 out of 73
# Processed and saved: subject_06_session_01.csv
# Shape: (134113, 18)
# Dans data : Nombre de 0.0 = 133632
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 42 out of 73
# Processed and saved: subject_06_session_02.csv
# Shape: (132385, 18)
# Dans data : Nombre de 0.0 = 131904
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 43 out of 73
# Processed and saved: subject_06_session_03.csv
# Shape: (137377, 18)
# Dans data : Nombre de 0.0 = 136896
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 44 out of 73
# Processed and saved: subject_06_session_04.csv
# Shape: (135425, 18)
# Dans data : Nombre de 0.0 = 134944
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 45 out of 73
# Processed and saved: subject_06_session_05.csv
# Shape: (133537, 18)
# Dans data : Nombre de 0.0 = 133056
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 46 out of 73
# Processed and saved: subject_06_session_06.csv
# Shape: (141281, 18)
# Dans data : Nombre de 0.0 = 140800
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 47 out of 73
# Processed and saved: subject_06_session_07.csv
# Shape: (134689, 18)
# Dans data : Nombre de 0.0 = 134208
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 48 out of 73
# Processed and saved: subject_06_session_08.csv
# Shape: (135489, 18)
# Dans data : Nombre de 0.0 = 135008
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 49 out of 73
# Processed and saved: subject_07_session_01.csv
# Shape: (166497, 18)
# Dans data : Nombre de 0.0 = 166016
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 50 out of 73
# Processed and saved: subject_07_session_02.csv
# Shape: (132673, 18)
# Dans data : Nombre de 0.0 = 132192
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 51 out of 73
# Processed and saved: subject_07_session_03.csv
# Shape: (138849, 18)
# Dans data : Nombre de 0.0 = 138368
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 52 out of 73
# Processed and saved: subject_07_session_04.csv
# Shape: (135521, 18)
# Dans data : Nombre de 0.0 = 135040
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 53 out of 73
# Processed and saved: subject_07_session_05.csv
# Shape: (138241, 18)
# Dans data : Nombre de 0.0 = 137760
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 54 out of 73
# Processed and saved: subject_07_session_06.csv
# Shape: (134785, 18)
# Dans data : Nombre de 0.0 = 134304
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 55 out of 73
# Processed and saved: subject_07_session_07.csv
# Shape: (133057, 18)
# Dans data : Nombre de 0.0 = 132576
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 56 out of 73
# Processed and saved: subject_07_session_08.csv
# Shape: (135777, 18)
# Dans data : Nombre de 0.0 = 135296
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 57 out of 73
# Processed and saved: subject_08_session_01.csv
# Shape: (126625, 18)
# Dans data : Nombre de 0.0 = 126144
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 58 out of 73
# Processed and saved: subject_09_session_01.csv
# Shape: (145377, 18)
# Dans data : Nombre de 0.0 = 144896
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 59 out of 73
# Processed and saved: subject_10_session_01.csv
# Shape: (130305, 18)
# Dans data : Nombre de 0.0 = 129824
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 60 out of 73
# Processed and saved: subject_11_session_01.csv
# Shape: (138017, 18)
# Dans data : Nombre de 0.0 = 137536
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 61 out of 73
# Processed and saved: subject_12_session_01.csv
# Shape: (139297, 18)
# Dans data : Nombre de 0.0 = 138816
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 62 out of 73
# Processed and saved: subject_13_session_01.csv
# Shape: (130145, 18)
# Dans data : Nombre de 0.0 = 129664
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 63 out of 73
# Processed and saved: subject_14_session_01.csv
# Shape: (139393, 18)
# Dans data : Nombre de 0.0 = 138912
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 64 out of 73
# Processed and saved: subject_15_session_01.csv
# Shape: (137505, 18)
# Dans data : Nombre de 0.0 = 137024
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 65 out of 73
# Processed and saved: subject_16_session_01.csv
# Shape: (135617, 18)
# Dans data : Nombre de 0.0 = 135136
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 66 out of 73
# Processed and saved: subject_17_session_01.csv
# Shape: (137409, 18)
# Dans data : Nombre de 0.0 = 136928
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 67 out of 73
# Processed and saved: subject_18_session_01.csv
# Shape: (133377, 18)
# Dans data : Nombre de 0.0 = 132896
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 68 out of 73
# Processed and saved: subject_19_session_01.csv
# Shape: (140097, 18)
# Dans data : Nombre de 0.0 = 139616
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 69 out of 73
# Processed and saved: subject_20_session_01.csv
# Shape: (131009, 18)
# Dans data : Nombre de 0.0 = 130528
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 70 out of 73
# Processed and saved: subject_21_session_01.csv
# Shape: (137185, 18)
# Dans data : Nombre de 0.0 = 136704
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 71 out of 73
# Processed and saved: subject_22_session_01.csv
# Shape: (139105, 18)
# Dans data : Nombre de 0.0 = 138624
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 72 out of 73
# Processed and saved: subject_23_session_01.csv
# Shape: (146081, 18)
# Dans data : Nombre de 0.0 = 145600
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
# File number 73 out of 73
# Processed and saved: subject_24_session_01.csv
# Shape: (134785, 18)
# Dans data : Nombre de 0.0 = 134304
# Dans data : Nombre de 1.0 = 400
# Dans data : Nombre de 2.0 = 80
# Dans data : Nombre de 16.0 = 1
